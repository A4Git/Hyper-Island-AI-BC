# %% [markdown]
# <a href="https://colab.research.google.com/github/A4Git/Hyper-Island-AI-BC/blob/main/Webscraping/2_Webscraping_1_workbook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Webscraping project 1 - workbook
#
# ## What are the most interesting question to ask from James Clears newsletter?
#
#
# One of my favorite newsletters i subscribe to is the [3-2-1 newsletter](https://jamesclear.com/3-2-1) by the author James Clear, who wrote the bestseller [Atomic habit](https://jamesclear.com/atomic-habits).
#
# ![Question](https://i.redd.it/d3nl7ol629h11.jpg)

# %% [markdown]
# ## The Goal

# %% [markdown]
# **The goal is to scrape the data from all the newsletters into an dataframe, sort only the last part of each newsletter, ie. the question:**
#
# ![q1](https://raw.githubusercontent.com/A4Git/Hyper-Island-AI-BC/main/Webscraping/img/bild.jpeg)

# %% [markdown]
# **The end result we are aming for is a csv file that looks like this one:**
# ![Goal](https://raw.githubusercontent.com/A4Git/Hyper-Island-AI-BC/main/Webscraping/img/bild_3.jpeg)

# %% [markdown]
# ### How to?

# %% [markdown]
# ![Coding](https://s3.amazonaws.com/rails-camp-tutorials/blog/programming+memes/programming-or-googling.jpg)
#
# ### Need help?
#
# #### There are a coupe of ways to get help:
# - **read the "docs" of the library you are working with. For the ones we are using today you can fint them here:**
#     - [ ] **[Requests](https://docs.python-requests.org/en/latest/)**,
#     - [ ] **[Beautiful Soup Documentation](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)**,
#     - [ ] **[pandas](https://pandas.pydata.org/docs/reference/io.html)**,
#     - [ ] **[requests-html](https://docs.python-requests.org/projects/requests-html/en/latest/)**.
#
# - **read a tutorial online:**
#     - for example this one from Real python - **[Beautiful Soup: Build a Web Scraper With Python](https://realpython.com/beautiful-soup-web-scraper-python/)**
#     - lookup some reference material online: - **[Python Requests Module](https://www.w3schools.com/python/module_requests.asp)**
#     - find some tutorials online, w3 is a great one : - **[w3's Pandas Tutorial](https://www.w3schools.com/python/pandas/default.asp), [Scraping Medium with Python & Beautiful Soup](https://www.google.com/search?q=web+scraping+medium&oq=medium+webscra&aqs=chrome.1.69i57j0i10i22i30j69i64.7671j0j1&sourceid=chrome&ie=UTF-8)**.
#
#
#
# - **If you have spend more then 30 min trying to solve one problem, then ask for help, first your crew and then me. I will go through the notebook and a solution this friday, before or after the TDS.**
#
#
# #### There are some build in help function that may be useful to try out as well:
# We can take a look at `os` library and the `dir(x)` and `help` functions.

# %%
import os
# The dir(library or funktion) shows you all the available commands
dir(os.curdir) # for example: we can take a look at some of the options available for the os.curdir (curent directory funktion):
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
#The help function is also helpful when you need to find out a bit more about the functions in the libraries we will be using:
help(os.chdir)
# Out:
# Help on built-in function chdir in module posix:
#
# chdir(path)
#     Change the current working directory to the specified path.
#
#     path may always be specified as a string.
#     On some platforms, path may also be specified as an open file descriptor.
#       If this functionality is unavailable, using it raises an exception.

# %%
type(os.chdir)
# Out:
# builtin_function_or_method

# %% [markdown]
# ### The Scope
#
# The scope of this notebook is to learn by doing. It's a barebone notebook with some code to get you started, some references and the end result we are aiming for. The rest (aka. googling, trying out code, and debugging is up to you, and that is in my opinion the best way to learn). Whenever possible, **write code**, even when you find it online as the ctrl +c /ctrl +v does not compute into learning.

# %% [markdown]
# The outline of this project include the following steps:
#
# * [ ] Downloading web pages using the requests library
# * [ ] Inspecting the HTML source code of a web page
# * [ ] Parsing parts of a website using Beautiful Soup
# * [ ] Writing parsed information into CSV files
#
# **First:**
# 1. Get it done (make a draft that runs without errors)
# 2. Then make it nice ( iterate over the draft and try to make it explainable, comment the code, give some context, etc.)

# %% [markdown]
# #### Install and import the libraries

# %% [markdown]
# If you don't have the libraries installed, just remove the `#` and run the code below:

# %%
# For step 1
# !pip install requests -q 
# !pip install pandas -q 
# !pip install beautifulsoup4 -q 

# For step 2 
# !pip install requests-html -q
# Out:
#      |████████████████████████████████| 83 kB 775 kB/s
#      |████████████████████████████████| 138 kB 26.3 MB/s
#      |████████████████████████████████| 111 kB 48.9 MB/s
#      |████████████████████████████████| 127 kB 49.7 MB/s
#   Building wheel for fake-useragent (setup.py) ... done
#   Building wheel for parse (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.

# %%
# The libraries we will be using today are:
import requests # for downloading the site
from bs4 import BeautifulSoup # for parsing the html download 
import pandas as pd  # for creating an dataframe and exporting it to a .csv file

# %% [markdown]
# ### Setup the query and url

# %%
url = 'https://jamesclear.com/3-2-1'

#now lets download the page
html = requests.get(url)

# if we get the code 200, then we know it's working and we got the page
html.status_code
# Out:
# 200

# %% [markdown]
# ### Inspect the website

# %% [markdown]
# Now lets take a look at the `html` code of the website by inspecting the site using developer tools. We'll do this to identify what to search for to get the data we want:
#
# ![Html](https://raw.githubusercontent.com/A4Git/Hyper-Island-AI-BC/main/Webscraping/img/bild_2.jpeg)
#
# We are looking for the tags like `div`, `p`, `a` and the `id` or `class`of the tags that hold the information we want. <br>

# %% [markdown]
# ### Extract the html data

# %% [markdown]
# Now, based on what you we in this page I want for each newsletter to extract the following data:
# - the article title
# - the newsletter date
# - the link to the whole newsletter page
# - the questions
#
# But before we get there we need to parse the `html` code we got back by downloading the site with `requests`.

# %%
# We use BS to read the html text
soup = BeautifulSoup(html.text, "html.parser") # html is just the parser for reading the html
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <!--[if IE 9]><html class="lt-ie10" lang="lang="en-US"" > <![endif]-->
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="https://use.typekit.net/tqf2ebt.css" rel="stylesheet"/>
#   <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots">
#    <!-- This site is optimized with the Yoast SEO Premium plugin v18.1 (Yoast SEO v18.3) - https://yoast.com/wordpress/plugins/seo/ -->
#    <title>
#     3-2-1 Thursday newsletter - James Clear
#    </title>
#    <link href="https://jamesclear.com/3-2-1" rel="canonical">
#     <meta content="en_US" property="og:locale">
#      <meta content="article" property="og:type">
#       <meta content="3-2-1 Thursday newsletter" property="og:title"/>
#       <meta content="https://jamesclear.com/3-2-1" property="og:url"/>
#       <meta content="James Clear" property="og:site_name"/>
#       <meta content="http://facebook.com/jamesclear" property="article:publisher"/>
#       <meta content="2021-12-03T00:42:01+00:00" property="article:modified_time"/>
#       <meta content="https://jamesclear.com/wp-content/uploads/2020/11/jc-twitter.png" property="og:image"/>
#       <meta content="1200" property="og:image:width"/>
#       <meta content="629" property="og:image:height"/>
#       <meta content="image/png" property="og:image:type"/>
#       <script class="yoast-schema-graph" type="application/ld+json">
#        {"@context":"https://schema.org","@graph":[{"@type":"WebSite","@id":"https://jamesclear.com/#website","url":"https://jamesclear.com/","name":"James Clear","description":"Ideas that never expire.","potentialAction":[{"@type":"SearchAction","target":{"@type":"EntryPoint","urlTemplate":"https://jamesclear.com/?s={search_term_string}"},"query-input":"required name=search_term_string"}],"inLanguage":"en-US"},{"@type":"ImageObject","@id":"https://jamesclear.com/3-2-1#primaryimage","inLanguage":"en-US","url":"https://jamesclear.com/wp-content/uploads/2020/11/jc-twitter.png","contentUrl":"https://jamesclear.com/wp-content/uploads/2020/11/jc-twitter.png","width":1200,"height":629},{"@type":"WebPage","@id":"https://jamesclear.com/3-2-1#webpage","url":"https://jamesclear.com/3-2-1","name":"3-2-1 Thursday newsletter - James Clear","isPartOf":{"@id":"https://jamesclear.com/#website"},"datePublished":"2019-08-08T19:32:16+00:00","dateModified":"2021-12-03T00:42:01+00:00","breadcrumb":{"@id":"https://jamesclear.com/3-2-1#breadcrumb"},"inLanguage":"en-US","potentialAction":[{"@type":"ReadAction","target":["https://jamesclear.com/3-2-1"]}]},{"@type":"BreadcrumbList","@id":"https://jamesclear.com/3-2-1#breadcrumb","itemListElement":[{"@type":"ListItem","position":1,"name":"Home","item":"https://jamesclear.com/"},{"@type":"ListItem","position":2,"name":"3-2-1 Thursday newsletter"}]}]}
#       </script>
#       <!-- / Yoast SEO Premium plugin. -->
#       <link href="//a.omappapi.com" rel="dns-prefetch"/>
#       <link href="//s.w.org" rel="dns-prefetch"/>
#       <link href="https://jamesclear.com/wp-content/plugins/wp-bigfoot-numeric/css/bigfoot-default.css?ver=5.9.2" id="wp-bigfoot-css" media="all" rel="stylesheet" type="text/css"/>
#       <link href="https://jamesclear.com/wp-includes/css/dist/block-library/style.min.css?ver=5.9.2" id="wp-block-library-css" media="all" rel="stylesheet" type="text/css"/>
#       <style id="global-styles-inline-css" type="text/css">
#        body{--wp--preset--color--black: #000000;--wp--preset--color--cyan-bluish-gray: #abb8c3;--wp--preset--color--white: #ffffff;--wp--preset--color--pale-pink: #f78da7;--wp--preset--color--vivid-red: #cf2e2e;--wp--preset--color--luminous-vivid-orange: #ff6900;--wp--preset--color--luminous-vivid-amber: #fcb900;--wp--preset--color--light-green-cyan: #7bdcb5;--wp--preset--color--vivid-green-cyan: #00d084;--wp--preset--color--pale-cyan-blue: #8ed1fc;--wp--preset--color--vivid-cyan-blue: #0693e3;--wp--preset--color--vivid-purple: #9b51e0;--wp--preset--gradient--vivid-cyan-blue-to-vivid-purple: linear-gradient(135deg,rgba(6,147,227,1) 0%,rgb(155,81,224) 100%);--wp--preset--gradient--light-green-cyan-to-vivid-green-cyan: linear-gradient(135deg,rgb(122,220,180) 0%,rgb(0,208,130) 100%);--wp--preset--gradient--luminous-vivid-amber-to-luminous-vivid-orange: linear-gradient(135deg,rgba(252,185,0,1) 0%,rgba(255,105,0,1) 100%);--wp--preset--gradient--luminous-vivid-orange-to-vivid-red: linear-gradient(135deg,rgba(255,105,0,1) 0%,rgb(207,46,46) 100%);--wp--preset--gradient--very-light-gray-to-cyan-bluish-gray: linear-gradient(135deg,rgb(238,238,238) 0%,rgb(169,184,195) 100%);--wp--preset--gradient--cool-to-warm-spectrum: linear-gradient(135deg,rgb(74,234,220) 0%,rgb(151,120,209) 20%,rgb(207,42,186) 40%,rgb(238,44,130) 60%,rgb(251,105,98) 80%,rgb(254,248,76) 100%);--wp--preset--gradient--blush-light-purple: linear-gradient(135deg,rgb(255,206,236) 0%,rgb(152,150,240) 100%);--wp--preset--gradient--blush-bordeaux: linear-gradient(135deg,rgb(254,205,165) 0%,rgb(254,45,45) 50%,rgb(107,0,62) 100%);--wp--preset--gradient--luminous-dusk: linear-gradient(135deg,rgb(255,203,112) 0%,rgb(199,81,192) 50%,rgb(65,88,208) 100%);--wp--preset--gradient--pale-ocean: linear-gradient(135deg,rgb(255,245,203) 0%,rgb(182,227,212) 50%,rgb(51,167,181) 100%);--wp--preset--gradient--electric-grass: linear-gradient(135deg,rgb(202,248,128) 0%,rgb(113,206,126) 100%);--wp--preset--gradient--midnight: linear-gradient(135deg,rgb(2,3,129) 0%,rgb(40,116,252) 100%);--wp--preset--duotone--dark-grayscale: url('#wp-duotone-dark-grayscale');--wp--preset--duotone--grayscale: url('#wp-duotone-grayscale');--wp--preset--duotone--purple-yellow: url('#wp-duotone-purple-yellow');--wp--preset--duotone--blue-red: url('#wp-duotone-blue-red');--wp--preset--duotone--midnight: url('#wp-duotone-midnight');--wp--preset--duotone--magenta-yellow: url('#wp-duotone-magenta-yellow');--wp--preset--duotone--purple-green: url('#wp-duotone-purple-green');--wp--preset--duotone--blue-orange: url('#wp-duotone-blue-orange');--wp--preset--font-size--small: 13px;--wp--preset--font-size--medium: 20px;--wp--preset--font-size--large: 36px;--wp--preset--font-size--x-large: 42px;}.has-black-color{color: var(--wp--preset--color--black) !important;}.has-cyan-bluish-gray-color{color: var(--wp--preset--color--cyan-bluish-gray) !important;}.has-white-color{color: var(--wp--preset--color--white) !important;}.has-pale-pink-color{color: var(--wp--preset--color--pale-pink) !important;}.has-vivid-red-color{color: var(--wp--preset--color--vivid-red) !important;}.has-luminous-vivid-orange-color{color: var(--wp--preset--color--luminous-vivid-orange) !important;}.has-luminous-vivid-amber-color{color: var(--wp--preset--color--luminous-vivid-amber) !important;}.has-light-green-cyan-color{color: var(--wp--preset--color--light-green-cyan) !important;}.has-vivid-green-cyan-color{color: var(--wp--preset--color--vivid-green-cyan) !important;}.has-pale-cyan-blue-color{color: var(--wp--preset--color--pale-cyan-blue) !important;}.has-vivid-cyan-blue-color{color: var(--wp--preset--color--vivid-cyan-blue) !important;}.has-vivid-purple-color{color: var(--wp--preset--color--vivid-purple) !important;}.has-black-background-color{background-color: var(--wp--preset--color--black) !important;}.has-cyan-bluish-gray-background-color{background-color: var(--wp--preset--color--cyan-bluish-gray) !important;}.has-white-background-color{background-color ...
#       </style>
#       <link href="https://jamesclear.com/wp-content/themes/jamesclear/dist/css/app-a9597f8324.css" id="nroom/css-css" media="all" rel="stylesheet" type="text/css"/>
#       <script id="jquery-core-js" src="https://jamesclear.com/wp-includes/js/jquery/jquery.min.js?ver=3.6.0" type="text/javascript">
#       </script>
#       <script id="jquery-migrate-js" src="https://jamesclear.com/wp-includes/js/jquery/jquery-migrate.min.js?ver=3.3.2" type="text/javascript">
#       </script>
#       <link href="https://jamesclear.com/wp-json/" rel="https://api.w.org/"/>
#       <link href="https://jamesclear.com/wp-json/wp/v2/pages/34990" rel="alternate" type="application/json"/>
#       <link href="https://jamesclear.com/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
#       <link href="https://jamesclear.com/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
#       <meta content="WordPress 5.9.2" name="generator"/>
#       <link href="https://jamesclear.com/?p=34990" rel="shortlink"/>
#       <link href="https://jamesclear.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fjamesclear.com%2F3-2-1" rel="alternate" type="application/json+oembed"/>
#       <link href="https://jamesclear.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fjamesclear.com%2F3-2-1&amp;format=xml" rel="alternate" type="text/xml+oembed"/>
#       <!-- Global site tag (gtag.js) - Google Analytics -->
#       <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-31053453-1">
#       </script>
#       <script>
#        window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-31053453-1');
#       </script>
#       <script async="" data-sparkloop="" src="https://dash.sparkloop.app/widget/MF218fb8b10e/embed.js">
#       </script>
#       <script src="https://www.googleoptimize.com/optimize.js?id=GTM-WDC9WDV">
#       </script>
#       <link href="https://jamesclear.com/wp-content/uploads/2020/11/cropped-icon-32x32.png" rel="icon" sizes="32x32"/>
#       <link href="https://jamesclear.com/wp-content/uploads/2020/11/cropped-icon-192x192.png" rel="icon" sizes="192x192"/>
#       <link href="https://jamesclear.com/wp-content/uploads/2020/11/cropped-icon-180x180.png" rel="apple-touch-icon"/>
#       <meta content="https://jamesclear.com/wp-content/uploads/2020/11/cropped-icon-270x270.png" name="msapplication-TileImage"/>
#       <style id="wp-custom-css" type="text/css">
#        .formkit-header,
# .formkit-subheader,
# .formkit-guarantee,
# .formkit-background{display: none;}
#
# .formkit-form {background: none !important;border: none !important;padding: 0 !important;}
#
# .formkit-form[data-uid="722b89e17b"][min-width~="600"] [data-style="minimal"] {padding: 0 !important;}
#
# .cta .formkit-form .formkit-field,
# .cta .formkit-form .formkit-submit{
# 	-webkit-flex: 100 1 auto !important;
#    -ms-flex: 100 1 auto !important;
#    flex: 100 1 auto !important;
# }
#
# .bonus__item__img {display: none;}
# .wp-block-button__link:active, .wp-block-button__link:focus, .wp-block-button__link:hover, .wp-block-button__link:visited {
#     color: #320101;
# }
# .clear-habits .testimonial__txt {font-size: 18px;line-height: 145%;}
# .clear-habits .atomic-habits-hero__col2 {padding: 0 5%;}
# .books__left a:hover {border: none;}
#
# .button-lines {position: relative;top: -3px;padding: 9px;-webkit-transform: none;-ms-transform: none;transform: none;}
#
# .button-lines:hover {background:none;box-shadow:none;}
#
# .formkit-form[data-uid="9193d0430c"] [data-group="checkboxes"] [data-group="checkbox"] label {
# 	font-size: 15px;
# 	line-height: 1.5em;
# }
#
# .page-id-39582 .cta,
# .page-id-20602 .cta,
# .page-id-6105 .cta,
# .page-id-40518 .cta
# {
# 	display: none;
# }
#       </style>
#      </meta>
#     </meta>
#    </link>
#   </meta>
#  </head>
#  <body class="page-template page-template-tpl-content page-template-tpl-content-php page page-id-34990 page-parent wp-embed-responsive theme--default">
#   <div class="main">
#    <header class="header">
#     <div class="container">
#      <div class="header__logo">
#       <div class="header__logo__img">
#        <a aria-label="Home" href="https://jamesclear.com">
#         <svg fill="none" height="13" viewbox="0 0 127 13" width="127" xmlns="http://www.w3.org/2000/svg">
#          <path d="M5.50562 8.36817C5.50562 9.24372 5.07328 10.2166 3.60011 10.2166C2.43118 10.2166 1.72662 8.96808 1.72662 8.96808L0.317505 10.1679C0.317505 10.1679 1.35833 12.065 3.60011 12.065C5.96999 12.065 7.42715 10.6868 7.42715 8.30331L7.42715 0.520602L5.50562 0.520602C5.50562 0.520602 5.50562 4.62274 5.50562 8.36817Z" fill="#111111">
#          </path>
#          <path d="M11.1178 11.8704H13.0554L14.0802 9.17887L18.8199 9.17887L19.8447 11.8704H21.7823L17.4268 0.520602L15.4733 0.520602L11.1178 11.8704ZM16.4501 2.96891L18.1314 7.39533H14.7687L16.4501 2.96891Z" fill="#111111">
#          </path>
#          <path d="M25.461 0.520602L25.461 11.8704L27.3825 11.8704L27.3825 4.24982L30.8893 9.64907L34.396 4.24982V11.8704H36.3176V0.520602L34.5402 0.520602L30.8893 6.22792L27.2384 0.520602L25.461 0.520602Z" fill="#111111">
#          </path>
#          <path d="M43.0136 2.369L47.8815 2.369V0.520602L41.0921 0.520602V11.8704H47.9776V10.022H43.0136V6.97376L47.4972 6.97376V5.12537L43.0136 5.12537V2.369Z" fill="#111111">
#          </path>
#        </span>
#        <span class="menu-close">
#         Close
#        </span>
#       </div>
#      </div>
#      <div class="header__right show-for-medium-up">
#       <a href="https://jamesclear.com/about">
#        About
#       </a>
#      </div>
#     </div>
#    </header>
#    <nav class="swipe-menu">
#     <a class=" menu-item menu-item-type-post_type menu-item-object-page menu-item-37174" href="https://jamesclear.com/books">
#      Books
#     </a>
#     <a class=" menu-item menu-item-type-post_type menu-item-object-page menu-item-37171" href="https://jamesclear.com/articles">
#      Articles
#     </a>
#     <a class=" menu-item menu-item-type-post_type menu-item-object-page current-menu-item page_item page-item-34990 current_page_item menu-item-37172" href="https://jamesclear.com/3-2-1">
#      Newsletter
#     </a>
#     <a class=" menu-item menu-item-type-post_type menu-item-object-page menu-item-38479" href="https://jamesclear.com/events">
#      Events
#     </a>
#     <a href="https://jamesclear.com/about">
#      About
#     </a>
#     <div class="swipe-menu__bg">
#      <svg fill="none" height="41" viewbox="0 0 48 41" width="48" xmlns="http://www.w3.org/2000/svg">
#       <path d="M3.14884 1.57442C3.14884 2.44395 2.44395 3.14884 1.57442 3.14884C0.704892 3.14884 0 2.44395 0 1.57442C0 0.704892 0.704892 0 1.57442 0C2.44395 0 3.14884 0.704892 3.14884 1.57442Z" fill="#B8AE84">
#       </path>
#       <path d="M25.1907 1.57442C25.1907 2.44395 24.4858 3.14884 23.6163 3.14884C22.7468 3.14884 22.0419 2.44395 22.0419 1.57442C22.0419 0.704892 22.7468 0 23.6163 0C24.4858 0 25.1907 0.704892 25.1907 1.57442Z" fill="#B8AE84">
#       </path>
#       <path d="M47.2326 1.57442C47.2326 2.44395 46.5277 3.14884 45.6582 3.14884C44.7887 3.14884 44.0838 2.44395 44.0838 1.57442C44.0838 0.704892 44.7887 0 45.6582 0C46.5277 0 47.2326 0.704892 47.2326 1.57442Z" fill="#B8AE84">
#       </path>
#       <path d="M14.1698 20.4675C14.1698 21.337 13.4649 22.0419 12.5954 22.0419C11.7258 22.0419 11.0209 21.337 11.0209 20.4675C11.0209 19.5979 11.7258 18.8931 12.5954 18.8931C13.4649 18.8931 14.1698 19.5979 14.1698 20.4675Z" fill="#B8AE84">
#       </path>
#       <path d="M36.2117 20.4675C36.2117 21.337 35.5068 22.0419 34.6373 22.0419C33.7677 22.0419 33.0628 21.337 33.0628 20.4675C33.0628 19.5979 33.7677 18.8931 34.6373 18.8931C35.5068 18.8931 36.2117 19.5979 36.2117 20.4675Z" fill="#B8AE84">
#       </path>
#       <path d="M25.1907 39.3605C25.1907 40.2301 24.4858 40.9349 23.6163 40.9349C22.7468 40.9349 22.0419 40.2301 22.0419 39.3605C22.0419 38.491 22.7468 37.7861 23.6163 37.7861C24.4858 37.7861 25.1907 38.491 25.1907 39.3605Z" fill="#B8AE84">
#       </path>
#      </svg>
#     </div>
#    </nav>
#    <div class="cta first" data-easygut-id="cta" id="block_5f4fcdc36e834">
#     <div class="container wp-block-columns">
#      <div class="cta__left">
#       <h2 class="cta__title section">
#        The 3-2-1 Newsletter
#       </h2>
#       <div class="cta__txt">
#        <p>
#         <em>
#          “The most wisdom per word of any newsletter on the web.”
#         </em>
#        </p>
#        <p>
#         The 3-2-1 Newsletter is one of the most popular newsletters in the world. Every Thursday, the latest issue is sent to over 1,000,000 people. Each message includes 3 short ideas from me, 2 quotes from others, and 1 question for you to ponder.
#        </p>
#        <p>
#         Enter your email and sign up for free right now.
#        </p>
#       </div>
#      </div>
#      <div class="cta__right">
#       <div class="cta__form">
#        <div class="form">
#         <h4 class="form__title">
#          Get the “3-2-1 Thursday” newsletter in your inbox
#         </h4>
#         <div class="form__input">
#          <script async="" data-uid="a595a7e2ce" src="https://jamesclear1.ck.page/a595a7e2ce/index.js">
#          </script>
#         </div>
#         <div class="form__txt">
#          No spam. Just the highest quality ideas you'll find on the web.
#         </div>
#        </div>
#        <div class="cta__dots">
#         <svg fill="none" height="43" viewbox="0 0 52 43" width="52" xmlns="http://www.w3.org/2000/svg">
#          <rect fill="#E2DDCA" height="2" rx="1" transform="rotate(-180 52 42.5)" width="2" x="52" y="42.5">
#          </rect>
#          <rect fill="#E2DDCA" height="2" rx="1" transform="rotate(-180 52 32.5)" width="2" x="52" y="32.5">
#          </rect>
#          <rect fill="#E2DDCA" height="2" rx="1" transform="rotate(-180 52 22.5)" width="2" x="52" y="22.5">
#          </rect>
#          <rect fill="#E2DDCA" height="2" rx="1" transform="rotate(-180 52 12.5)" width="2" x="52" y="12.5">
#          </rect>
#          <rect fill="#E2DDCA" height="2" rx="1" transform="rotate(-180 42 42.5)" width="2" x="42" y="42.5">
#          </rect>
#          <rect fill="#E2DDCA" height="2" rx="1" transform="rotate(-180 32 32.5)" width="2" x="32" y="32.5">
#          </rect>
#          <rect fill="#E2DDCA" height="2" rx="1" transform="rotate(-180 42 22.5)" width="2" x="42" y="22.5">
#          </rect>
#          <rect fill="#E2DDCA" height="2" rx="1" transform="rotate(-180 42 2.5)" width="2" x="42" y="2.5">
#          </rect>
#          <rect fill="#E2DDCA" height="2" rx="1" transform="rotate(-180 22 12.5)" width="2" x="22" y="12.5">
#          </rect>
#          <rect fill="#E2DDCA" height="2" rx="1" transform="rotate(-180 22 22.5)" width="2" x="22" y="22.5">
#          </rect>
#          <rect fill="#E2DDCA" height="2" rx="1" transform="rotate(-180 2 2.5)" width="2" x="2" y="2.5">
#          </rect>
#          <rect fill="#E2DDCA" height="2" rx="1" transform="rotate(-180 32 42.5)" width="2" x="32" y="42.5">
#          </rect>
#         </svg>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="all-articles " data-easygut-id="allarticles" id="block_5f4fd823532b8">
#     <div class="container">
#      <div class="dots">
#       <svg fill="none" height="41" viewbox="0 0 48 41" width="48" xmlns="http://www.w3.org/2000/svg">
#        <path d="M3.14884 1.57442C3.14884 2.44395 2.44395 3.14884 1.57442 3.14884C0.704892 3.14884 0 2.44395 0 1.57442C0 0.704892 0.704892 0 1.57442 0C2.44395 0 3.14884 0.704892 3.14884 1.57442Z" fill="#B8AE84">
#        </path>
#        <path d="M25.1907 1.57442C25.1907 2.44395 24.4858 3.14884 23.6163 3.14884C22.7468 3.14884 22.0419 2.44395 22.0419 1.57442C22.0419 0.704892 22.7468 0 23.6163 0C24.4858 0 25.1907 0.704892 25.1907 1.57442Z" fill="#B8AE84">
#        </path>
#        <path d="M47.2326 1.57442C47.2326 2.44395 46.5277 3.14884 45.6582 3.14884C44.7887 3.14884 44.0838 2.44395 44.0838 1.57442C44.0838 0.704892 44.7887 0 45.6582 0C46.5277 0 47.2326 0.704892 47.2326 1.57442Z" fill="#B8AE84">
#        </path>
#        <path d="M14.1698 20.4675C14.1698 21.337 13.4649 22.0419 12.5954 22.0419C11.7258 22.0419 11.0209 21.337 11.0209 20.4675C11.0209 19.5979 11.7258 18.8931 12.5954 18.8931C13.4649 18.8931 14.1698 19.5979 14.1698 20.4675Z" fill="#B8AE84">
#        </path>
#        <path d="M36.2117 20.4675C36.2117 21.337 35.5068 22.0419 34.6373 22.0419C33.7677 22.0419 33.0628 21.337 33.0628 20.4675C33.0628 19.5979 33.7677 18.8931 34.6373 18.8931C35.5068 18.8931 36.2117 19.5979 36.2117 20.4675Z" fill="#B8AE84">
#          </a>
#         </div>
#        </div>
#        <div class="all-articles__news__posts">
#         <div class="all-articles__news__date">
#          Feb 4
#         </div>
#         <div>
#          <a class="all-articles__news__post" href="https://jamesclear.com/3-2-1/february-4-2021">
#           3-2-1: On teaching, mastery, and working on important problems
#          </a>
#         </div>
#        </div>
#        <div class="all-articles__news__posts">
#         <div class="all-articles__news__date">
#          Jan 28
#         </div>
#         <div>
#          <a class="all-articles__news__post" href="https://jamesclear.com/3-2-1/january-28-2021">
#           3-2-1: On being in the right room, confidence, and taking action
#          </a>
#         </div>
#        </div>
#        <div class="all-articles__news__posts">
#         <div class="all-articles__news__date">
#          Jan 21
#         </div>
#         <div>
#          <a class="all-articles__news__post" href="https://jamesclear.com/3-2-1/january-21-2021">
#           3-2-1: On fulfilling your potential, self-esteem, and the power of books
#          </a>
#         </div>
#        </div>
#        <div class="all-articles__news__posts">
#         <div class="all-articles__news__date">
#          Jan 14
#         </div>
#         <div>
#          <a class="all-articles__news__post" href="https://jamesclear.com/3-2-1/january-14-2021">
#           3-2-1: A brief guide to leadership, and when to value feedback
#          </a>
#         </div>
#        </div>
#        <div class="all-articles__news__posts">
#         <div class="all-articles__news__date">
#          Jan 7
#         </div>
#         <div>
#          <a class="all-articles__news__post" href="https://jamesclear.com/3-2-1/january-7-2021">
#           3-2-1: On maturity, how to do exceptional work, and the connectedness of things
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="all-articles__news">
#       <div class="all-articles__news__year">
#        2020
#       </div>
#       <div class="all-articles__news__title">
#        <div class="all-articles__news__posts">
#         <div class="all-articles__news__date">
#          Dec 31
#         </div>
#         <div>
#          <a class="all-articles__news__post" href="https://jamesclear.com/3-2-1/december-31-2020">
#           3-2-1: On systems vs. goals, endings, and the importance of leverage
#          </a>
#         </div>
#        </div>
#        <div class="all-articles__news__posts">
#         <div class="all-articles__news__date">
#          Dec 24
#         </div>
#         <div>
#          <a class="all-articles__news__post" href="https://jamesclear.com/3-2-1/december-24-2020">
#           3-2-1:  On the most important conversation, the value of time, and trusting your gut
#          </a>
#         </div>
#        </div>
#        <div class="all-articles__news__posts">
#         <div class="all-articles__news__date">
#          Dec 17
#         </div>
#         <div>
#          <a class="all-articles__news__post" href="https://jamesclear.com/3-2-1/december-17-2020">
#           3-2-1: On blame, the purpose of education, and compounding choices
#          </a>
#         </div>
#        </div>
#        <div class="all-articles__news__posts">
# ...
#           3-2-1: On gut reactions, negotiation tips, perseverance, and making better decisions
#          </a>
#         </div>
#        </div>
#        <div class="all-articles__news__posts">
#         <div class="all-articles__news__date">
#          Oct 3
#         </div>
#         <div>
#          <a class="all-articles__news__post" href="https://jamesclear.com/3-2-1/october-3-2019">
#           3-2-1: On the costs of habits, major life changes, and what money can't buy
#          </a>
#         </div>
#        </div>
#        <div class="all-articles__news__posts">
#         <div class="all-articles__news__date">
#          Sep 26
#         </div>
#         <div>
#          <a class="all-articles__news__post" href="https://jamesclear.com/3-2-1/september-26-2019">
#           3-2-1: On editing your own work, being original, and failure
#          </a>
#         </div>
#        </div>
#        <div class="all-articles__news__posts">
#         <div class="all-articles__news__date">
#          Sep 19
#         </div>
#         <div>
#          <a class="all-articles__news__post" href="https://jamesclear.com/3-2-1/september-19-2019">
#           3-2-1: On comparison, consistency, and what’s not going to change
#          </a>
#         </div>
#        </div>
#        <div class="all-articles__news__posts">
#         <div class="all-articles__news__date">
#          Sep 12
#         </div>
#         <div>
#          <a class="all-articles__news__post" href="https://jamesclear.com/3-2-1/september-12-2019">
#           3-2-1: On mistakes of ambition vs. sloth, innovation, and being reliable
#          </a>
#         </div>
#        </div>
#        <div class="all-articles__news__posts">
#         <div class="all-articles__news__date">
#          Sep 5
#         </div>
#         <div>
#          <a class="all-articles__news__post" href="https://jamesclear.com/3-2-1/september-5-2019">
#           3-2-1: On problem solving, tough-minded optimism, and courage
#          </a>
#         </div>
#        </div>
#        <div class="all-articles__news__posts">
#         <div class="all-articles__news__date">
#          Aug 29
#         </div>
#         <div>
#          <a class="all-articles__news__post" href="https://jamesclear.com/3-2-1/august-29-2019">
#           3-2-1: On feeling misunderstood, thinking clearly, and making the most of your one life
#          </a>
#         </div>
#        </div>
#        <div class="all-articles__news__posts">
#         <div class="all-articles__news__date">
#          Aug 22
#         </div>
#         <div>
#          <a class="all-articles__news__post" href="https://jamesclear.com/3-2-1/august-22-2019">
#           3-2-1: On increasing intelligence, networking, and shooting for the top
#          </a>
#         </div>
#        </div>
#        <div class="all-articles__news__posts">
#         <div class="all-articles__news__date">
#          Aug 15
#         </div>
#         <div>
#          <a class="all-articles__news__post" href="https://jamesclear.com/3-2-1/august-15-2019">
#           3-2-1: On mastery, learning to let go of trivial arguments, and bias
#          </a>
#         </div>
#        </div>
#        <div class="all-articles__news__posts">
#         <div class="all-articles__news__date">
#          Aug 8
#         </div>
#         <div>
#          <a class="all-articles__news__post" href="https://jamesclear.com/3-2-1/august-8-2019">
#           3-2-1: On the lessons of history, imperfect starts, and critiquing your own work
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="cta " data-easygut-id="cta" id="block_5f4fda17532b9">
#     <div class="container wp-block-columns">
#      <div class="cta__left">
#       <h2 class="cta__title section">
#        3-2-1 Thursday newsletter
#       </h2>
#       <div class="cta__txt">
#        <p>
#         Every Thursday, I send out my “3-2-1” newsletter with 3 ideas from me, 2 quotes from others, and 1 question for you. Sign up with the form below to get a new edition in your inbox every week.
#        </p>
#        <p>
#         The goal of each 3-2-1 email is to share the most wisdom per word of any newsletter on the web. While my long-form articles allow me to explore one idea in-depth, these emails will cover a wide range of useful ideas each week.
#        </p>
#       </div>
#      </div>
#      <div class="cta__right">
#       <div class="cta__form">
#        <div class="form">
#         <h4 class="form__title">
#          Get the 3-2-1 Thursday newsletter in your inbox
#         </h4>
#         <div class="form__input">
#          <script async="" data-uid="722b89e17b" src="https://jamesclear1.ck.page/722b89e17b/index.js">
#          </script>
#         </div>
#         <div class="form__txt">
#          No spam. Just the highest quality ideas you’ll find on the web.
#         </div>
#        </div>
#        <div class="cta__dots">
#         <svg fill="none" height="43" viewbox="0 0 52 43" width="52" xmlns="http://www.w3.org/2000/svg">
#          <rect fill="#E2DDCA" height="2" rx="1" transform="rotate(-180 52
#        </path>
#        <path d="M265.117 36.3602H286.198V30.5384L271.169 30.5384V0.61281L265.117 0.61281V36.3602Z" fill="white">
#        </path>
#        <path d="M303.951 6.43452L319.283 6.43452V0.61281L297.899 0.61281V36.3602H319.585V30.5384H303.951V20.9377H318.072V15.116L303.951 15.116V6.43452Z" fill="white">
#        </path>
#        <path d="M329.566 36.3602L335.669 36.3602L338.896 27.8829L353.825 27.8829L357.053 36.3602H363.155L349.437 0.61281L343.284 0.61281L329.566 36.3602ZM346.361 8.32402L351.656 22.2655L341.065 22.2655L346.361 8.32402Z" fill="white">
#        </path>
#        <path d="M374.741 36.3602L380.793 36.3602V22.8783H383.567L391.939 36.3602H399L390.174 22.4698C395.217 21.1931 398.042 17.1077 398.042 11.7456C398.042 5.2089 393.351 0.61281 386.341 0.61281L374.741 0.61281V36.3602ZM385.585 17.0566H380.793V6.43452L385.585 6.43452C389.468 6.43452 391.889 8.22189 391.889 11.7456C391.889 15.2692 389.468 17.0566 385.585 17.0566Z" fill="white">
#        </path>
#       </svg>
#      </a>
#     </div>
#    </div>
#    <div class="container wp-block-columns">
#     <div class="footer__info wp-block-column" style="flexBasis: 50%;">
#      <div class="footer__txt">
#       <div>
#        Thanks for reading. It makes a difference. I donate 5 percent of profits to causes that improve the health of children, pregnant mothers, and families in low income communities. We have helped over 30,000 people so far.
#       </div>
#       <div class="footer__partners">
#        <div class="footer__partners__item">
#         <a href="/privacy-policy">
#          Privacy &amp; Terms of Use
#         </a>
#        </div>
#        <div class="footer__partners__item">
#         <a href="https://www.liquidweb.com/partner-community/get-started/?irgwc=1&amp;clickid=RIjW5XQW8xyJRi-wUx0Mo382UklXPh3BrRl%3AS80&amp;iradid=619008&amp;irpid=1906336&amp;sharedid=&amp;_ir=1&amp;utm_source=1906336&amp;utm_medium=affiliate&amp;utm_term=IR&amp;utm_content=619008" target="_blank">
#          Hosting by LiquidWeb
#         </a>
#        </div>
#        <div class="footer__partners__item">
#         <a href="https://optinmonster.com/" target="_blank">
#          Forms by OptinMonster
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="footer__menus wp-block-column" style="flexBasis: 50%;">
#      <div class="footer__menu footer__menu_1">
#       <div class="footer__title">
#        Ideas
#       </div>
#       <ul class="footer__menu__list footer__list">
#        <li>
#         <a class="footer__link" href="https://jamesclear.com/articles">
#          Articles
#         </a>
#        </li>
#        <li>
#         <a class="footer__link" href="https://jamesclear.com/3-2-1">
#          Newsletter
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="footer__menu footer__menu_2">
#       <div class="footer__title">
#        Books
#       </div>
#       <ul class="footer__menu__list footer__list">
#        <li>
#         <a class="footer__link" href="https://jamesclear.com/atomic-habits">
#          Atomic Habits
#         </a>
#        </li>
#        <li>
#         <a class="footer__link" href="https://jamesclear.com/habit-journal">
#          Habit Journal
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="footer__menu footer__menu_3">
#       <div class="footer__title">
#        Links
#       </div>
#       <ul class="footer__menu__list footer__list">
#        <li>
#         <a class="footer__link" href="https://twitter.com/jamesclear">
#          Twitter
#         </a>
#        </li>
#        <li>
#         <a class="footer__link" href="https://www.instagram.com/jamesclear/">
#          Instagram
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#    </div>
#   </footer>
#   <!-- This site is converting visitors into subscribers and customers with OptinMonster - https://optinmonster.com :: Campaign Title: 30 Days to Better Habits – Test 1 -->
#   <script>
#    (function(d,u,ac){var s=d.createElement('script');s.type='text/javascript';s.src='https://a.omappapi.com/app/js/api.min.js';s.async=true;s.dataset.user=u;s.dataset.campaign=ac;d.getElementsByTagName('head')[0].appendChild(s);})(document,83350,'vr2fxurjddl77uzy0orw');
#   </script>
#   <!-- / OptinMonster -->
#   <!-- This site is converting visitors into subscribers and customers with OptinMonster - https://optinmonster.com :: Campaign Title: 3-2-1 – Test 6 (photo) -->
#   <script>
#    (function(d,u,ac){var s=d.createElement('script');s.type='text/javascript';s.src='https://a.omappapi.com/app/js/api.min.js';s.async=true;s.dataset.user=u;s.dataset.campaign=ac;d.getElementsByTagName('head')[0].appendChild(s);})(document,83350,'cup8nxbwamq9d0afqqij');
#   </script>
#   <!-- / OptinMonster -->
#   <!-- This site is converting visitors into subscribers and customers with OptinMonster - https://optinmonster.com :: Campaign Title: 3-2-1 – Mobile – Test 2 -->
#   <script>
#    (function(d,u,ac){var s=d.createElement('script');s.type='text/javascript';s.src='https://a.omappapi.com/app/js/api.min.js';s.async=true;s.dataset.user=u;s.dataset.campaign=ac;d.getElementsByTagName('head')[0].appendChild(s);})(document,83350,'s05sr9jecaadtxq3jxyz');
#   </script>
#   <!-- / OptinMonster -->
#   <script type="text/javascript">
#    var vr2fxurjddl77uzy0orw_shortcode = true;var cup8nxbwamq9d0afqqij_shortcode = true;var s05sr9jecaadtxq3jxyz_shortcode = true;
#   </script>
#   <script id="bigfoot-js" src="https://jamesclear.com/wp-content/plugins/wp-bigfoot-numeric/js/bigfoot.min.js?ver=1.4.0" type="text/javascript">
#   </script>
#   <script id="wp-bigfoot-js" src="https://jamesclear.com/wp-content/plugins/wp-bigfoot-numeric/js/wp-bigfoot.js?ver=1.4.0" type="text/javascript">
#   </script>
#   <script id="convertkit-js-js-extra" type="text/javascript">
#    /* <![CDATA[ */
# var convertkit = {"ajaxurl":"https:\/\/jamesclear.com\/wp-admin\/admin-ajax.php","debug":"","nonce":"c0873ade74","subscriber_id":"0","tag":"","post_id":"34990"};
# /* ]]> */
#   </script>
#   <script id="convertkit-js-js" src="https://jamesclear.com/wp-content/plugins/convertkit/resources/frontend/js/convertkit.js?ver=1.9.7.0" type="text/javascript">
#   </script>
#   <script>
#    (function(d){var s=d.createElement("script");s.type="text/javascript";s.src="https://a.omappapi.com/app/js/api.min.js";s.async=true;s.id="omapi-script";d.getElementsByTagName("head")[0].appendChild(s);})(document);
#   </script>
#   <script id="nroom/js-js" src="https://jamesclear.com/wp-content/themes/jamesclear/dist/js/app-0c0a6674c0.js" type="text/javascript">
#   </script>
#   <script id="optinmonster-wp-helper-js" src="https://jamesclear.com/wp-content/plugins/optinmonster/assets/js/helper.js?ver=2.6.11" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var omapi_localized = {
# 			ajax: 'https://jamesclear.com/wp-admin/admin-ajax.php?optin-monster-ajax-route=1',
# 			nonce: '33e9e8e4fa',
# 			slugs:
# 			{"vr2fxurjddl77uzy0orw":{"slug":"vr2fxurjddl77uzy0orw","mailpoet":false},"cup8nxbwamq9d0afqqij":{"slug":"cup8nxbwamq9d0afqqij","mailpoet":false},"s05sr9jecaadtxq3jxyz":{"slug":"s05sr9jecaadtxq3jxyz","mailpoet":false}}		};
#   </script>
#   <script type="text/javascript">
#    var omapi_data = {"wc_cart":[],"object_id":34990,"object_key":"page","object_type":"post","term_ids":[]};
#   </script>
#  </body>
# </html>

# %% [markdown]
# ### Prototype the model with a single record

# %%
#Lets try to get major tag for all the links 
all_divs = ??

for y in all_divs:
    print(y.text)
# Out:
# 2022
# 2021
# 2020
# 2019

# %%
# lets try to get the date tip: try `.text.strip()` to get only the date)
date = soup.find('div', class_='all-articles__news__date').text.strip()
date
# Out:
# 'Mar 17'

# %%
# and the title (tip: try `.text` to get only the title)
title = ??
title
# Out:
# '3-2-1: Charity, the true mark of a pro, and how to choose what to read'

# %%
#how about the link to the newsletter 
lnk = ??
lnk
# Out:
# 'https://jamesclear.com/3-2-1/march-17-2022'

# %% [markdown]
# ### Generalize the model with a function
#
# Now put all the code into a function (or several).

# %%
article_list = []
def get_newsletter_links():
    ??
    return article_list.append(??)

get_newsletter_links()
# Out:
# 1

# %%
# Now we can try to get the content of each newsletter
def get_page(url):
    """Download a web page and return a beautiful soup doc"""
    # Download the page
    response = requests.get(url)
    
    # Check if download was sucessful
    if response.status_code ???:
      ???
    # Get the page HTML
    page_content = response.text
    
    # Create a bs4 doc
    soup = ??
    return soup

# %%
# Once we get the soup for each newsletter we can try to get the data we need:
def get_newsletter():
    ??

# %% [markdown]
# ### Putting it all together

# %%
# function 1
??
# function 2
??
# function 3
??

# %%
# Save the results to a csv named "JC_newsletter.csv"
??

# %% [markdown]
# ## Now lets try the requests-html library (part 2)
# New lets see how we can make it a bit more efficinent with one integrated library, the `requests-html`. The `request-html` is writen by the creator of `request` but includes `html` parser so we don't need `beatiful soup` to read the `html`.

# %%
from requests_html import HTMLSession
session = HTMLSession()
r = session.get('https://jamesclear.com/3-2-1')

# %%
##Now lets see all the links
r.html.absolute_links
# Out:
# {'https://jamesclear.com',
#  'https://jamesclear.com/3-2-1',
#  'https://jamesclear.com/3-2-1/april-1-2021',
#  'https://jamesclear.com/3-2-1/april-15-2021',
#  'https://jamesclear.com/3-2-1/april-16-2020',
#  'https://jamesclear.com/3-2-1/april-2-2020',
#  'https://jamesclear.com/3-2-1/april-22-2021',
#  'https://jamesclear.com/3-2-1/april-23-2020',
#  'https://jamesclear.com/3-2-1/april-29-2021',
#  'https://jamesclear.com/3-2-1/april-30-2020',
#  'https://jamesclear.com/3-2-1/april-8-2021',
#  'https://jamesclear.com/3-2-1/april-9-2020',
#  'https://jamesclear.com/3-2-1/august-12-2021',
#  'https://jamesclear.com/3-2-1/august-13-2020',
#  'https://jamesclear.com/3-2-1/august-15-2019',
#  'https://jamesclear.com/3-2-1/august-19-2021',
#  'https://jamesclear.com/3-2-1/august-20-2020',
#  'https://jamesclear.com/3-2-1/august-22-2019',
#  'https://jamesclear.com/3-2-1/september-2-2021',
#  'https://jamesclear.com/3-2-1/september-23-2021',
#  'https://jamesclear.com/3-2-1/september-24-2020',
#  'https://jamesclear.com/3-2-1/september-26-2019',
#  'https://jamesclear.com/3-2-1/september-3-2020',
#  'https://jamesclear.com/3-2-1/september-30-2021',
#  'https://jamesclear.com/3-2-1/september-5-2019',
#  'https://jamesclear.com/3-2-1/september-9-2021',
#  'https://jamesclear.com/about',
#  'https://jamesclear.com/articles',
#  'https://jamesclear.com/atomic-habits',
#  'https://jamesclear.com/books',
#  'https://jamesclear.com/events',
#  'https://jamesclear.com/habit-journal',
#  'https://jamesclear.com/privacy-policy',
#  'https://optinmonster.com/',
#  'https://twitter.com/jamesclear',
#  'https://www.instagram.com/jamesclear/',
#  'https://www.liquidweb.com/partner-community/get-started/?irgwc=1&clickid=RIjW5XQW8xyJRi-wUx0Mo382UklXPh3BrRl%3AS80&iradid=619008&irpid=1906336&sharedid=&_ir=1&utm_source=1906336&utm_medium=affiliate&utm_term=IR&utm_content=619008'}

# %% [markdown]
# Now we can get all the relevant links with a [list comprehension](https://realpython.com/list-comprehension-python/)

# %%
nl_links= [link for link in r.html.absolute_links if "/3-2-1/" in link]
len(nl_links) # we got 137 newsletter links
# Out:
# 137

# %%
#Lets try to get only the title of the newsletter
all = r.html.find('.all-articles__news__post')
all[0].text.strip().replace("3-2-1:", "")
# Out:
# ' Charity, the true mark of a pro, and how to choose what to read'

# %%
#Now lets get all the newsletters and links
article_list = []

all = r.html.find('.all-articles__news__post')
for item in all: 
    titel = item.find('.all-articles__news__post', first=True).text.replace("3-2-1:", " ")
    link = item.find('.all-articles__news__post', first=True).links
    article = {
        'Titel' : titel,
        'Url' : link
        }
    article_list.append(article)

len(article_list)
# Out:
# 137

# %%
# Now lets explore how to get the questions from each newsletter,
# But first we should try it with a smal sample of the newsletters
test_nl_links = nl_links[:10]
len(test_nl_links), test_nl_links
# Out:
# (10,
#  ['https://jamesclear.com/3-2-1/june-3-2021',
#   'https://jamesclear.com/3-2-1/december-9-2021',
#   'https://jamesclear.com/3-2-1/june-4-2020',
#   'https://jamesclear.com/3-2-1/march-3-2022',
#   'https://jamesclear.com/3-2-1/december-17-2020',
#   'https://jamesclear.com/3-2-1/january-23-2020',
#   'https://jamesclear.com/3-2-1/august-19-2021',
#   'https://jamesclear.com/3-2-1/january-30-2020',
#   'https://jamesclear.com/3-2-1/november-19-2020',
#   'https://jamesclear.com/3-2-1/may-13-2021'])

# %%
# For now this is what we have in terms of questions:
for nl in test_nl_links:
    get_nl = session.get(nl)
    #url = get_nl.url
    #date= get_nl.url.rsplit("/")[4].replace('-',' ').capitalize()
    #question_header = get_nl.html.find('h2', containing='1 QUESTION', first=True).text,
    question = get_nl.html.find("h2#h-1-question-for-you~p", first=True).full_text.strip()
    print(question)
# Out:
# Do the people around me act the way I wish to act?
# Are you playing a game worth winning?
# What is the biggest small thing I could do today?
# Think of something you struggled with in the last year. If you step back and zoom out, what is one lesson you have learned from the experience?
# What is one small thing I could do today that would make a meaningful impact on my future?
# Am I tolerating my flaws or improving them?
# Six months from now, what you will you wish you had spent time on today?
# Will this matter in six months?
# What would your closest friend tell you to do?
# What is a small pleasure that brings me great joy? Can I enjoy it today?

# %%
# Now lets try to put it togehter in a function 

data = []

for nl in test_nl_links:
    get_nl = session.get(nl)
    title = get_nl.html.find("div.page__header>h1", first=True).text.replace("3-2-1:", "")
    url = get_nl.url
    date= get_nl.url.rsplit("/")[4].replace('-',' ').capitalize()
    try:
        question = get_nl.html.find("h2#h-1-question-for-you~p", first=True).full_text.strip()
    except: 
        pass
    data.append([date, title, question, url])

data
# Out:
# [['June 3 2021',
#   ' On growth, all-or-nothing mindsets, and how great art evolves with us',
#   'Do the people around me act the way I wish to act?',
#   'https://jamesclear.com/3-2-1/june-3-2021'],
#  ['December 9 2021',
#   ' Active patience, focusing on what you can control, and playing a game worth winning',
#   'Are you playing a game worth winning?',
#   'https://jamesclear.com/3-2-1/december-9-2021'],
#  ['June 4 2020',
#   ' On taking action, changing incentives, and belonging',
#   'What is the biggest small thing I could do today?',
#   'https://jamesclear.com/3-2-1/june-4-2020'],
#  ['March 3 2022',
#   ' Doubling your intelligence, zooming out, and finding value in anger',
#   'Think of something you struggled with in the last year. If you step back and zoom out, what is one lesson you have learned from the experience?',
#   'https://jamesclear.com/3-2-1/march-3-2022'],
#  ['December 17 2020',
#   ' On blame, the purpose of education, and compounding choices',
#   'What is one small thing I could do today that would make a meaningful impact on my future?',
#   'https://jamesclear.com/3-2-1/december-17-2020'],
#  ['January 23 2020',
#   ' On minimalism, reading, status, and friendship',
#   'Am I tolerating my flaws or improving them?',
#   'https://jamesclear.com/3-2-1/january-23-2020'],
#  ['August 19 2021',
#   ' Planning for failure and preparing for luck',
#   'Six months from now, what you will you wish you had spent time on today?',
#   'https://jamesclear.com/3-2-1/august-19-2021'],
#  ['January 30 2020',
#   ' On mental toughness, self-awareness, and providing value',
#   'Will this matter in six months?',
#   'https://jamesclear.com/3-2-1/january-30-2020'],
#  ['November 19 2020',
#   ' On progress, friendship, and how to improve your writing',
#   'What would your closest friend tell you to do?',
#   'https://jamesclear.com/3-2-1/november-19-2020'],
#  ['May 13 2021',
#   ' On character, the process of improvement, and mastering one thing',
#   'What is a small pleasure that brings me great joy? Can I enjoy it today?',
#   'https://jamesclear.com/3-2-1/may-13-2021']]

# %%
#Now we can try to get all the questions: 

all_newsletter_data = []

for nl in nl_links:
    r = session.get(nl)
    title = r.html.find("div.page__header>h1", first=True).text.replace("3-2-1:", "")
    url = r.url
    date= r.url.rsplit("/")[4].replace('-',' ').capitalize()
    try:
        question = r.html.find("h2#h-1-question-for-you~p", first=True).full_text.strip()
    except: 
        pass
    all_newsletter_data.append([date, title, question, url ]) 

all_newsletter_data
# Out:
# [['June 3 2021',
#   ' On growth, all-or-nothing mindsets, and how great art evolves with us',
#   'Do the people around me act the way I wish to act?',
#   'https://jamesclear.com/3-2-1/june-3-2021'],
#  ['December 9 2021',
#   ' Active patience, focusing on what you can control, and playing a game worth winning',
#   'Are you playing a game worth winning?',
#   'https://jamesclear.com/3-2-1/december-9-2021'],
#  ['June 4 2020',
#   ' On taking action, changing incentives, and belonging',
#   'What is the biggest small thing I could do today?',
#   'https://jamesclear.com/3-2-1/june-4-2020'],
#  ['March 3 2022',
#   ' Doubling your intelligence, zooming out, and finding value in anger',
#   'Think of something you struggled with in the last year. If you step back and zoom out, what is one lesson you have learned from the experience?',
#   'https://jamesclear.com/3-2-1/march-3-2022'],
#  ['December 17 2020',
#   ' On blame, the purpose of education, and compounding choices',
#   'What is one small thing I could do today that would make a meaningful impact on my future?',
#   'https://jamesclear.com/3-2-1/december-17-2020'],
#  ['January 23 2020',
#   ' On minimalism, reading, status, and friendship',
#   'Am I tolerating my flaws or improving them?',
#   'https://jamesclear.com/3-2-1/january-23-2020'],
#  ['August 19 2021',
#   ' Planning for failure and preparing for luck',
#   'Six months from now, what you will you wish you had spent time on today?',
#   'https://jamesclear.com/3-2-1/august-19-2021'],
#  ['January 30 2020',
#   ' On mental toughness, self-awareness, and providing value',
#   'Will this matter in six months?',
#   'https://jamesclear.com/3-2-1/january-30-2020'],
#  ['November 19 2020',
#   ' On progress, friendship, and how to improve your writing',
#   'What would your closest friend tell you to do?',
#   'https://jamesclear.com/3-2-1/november-19-2020'],
#  ['May 13 2021',
#   ' On character, the process of improvement, and mastering one thing',
#   'What is a small pleasure that brings me great joy? Can I enjoy it today?',
#   'https://jamesclear.com/3-2-1/may-13-2021'],
#  ['September 3 2020',
#   ' On patience, vision, and emphasizing joy',
#   "What are the 1-2 things that if you get them done today, you'll go to bed content?",
#   'https://jamesclear.com/3-2-1/september-3-2020'],
#  ['April 9 2020',
#   ' On control, saying no, and keeping an open mind',
#   'Can you sit still, do nothing, and breathe deeply for the next two minutes?',
#   'https://jamesclear.com/3-2-1/april-9-2020'],
#  ['September 9 2021',
#   ' How friendship happens, letting go, and revision',
#   'What do you need to de-prioritize?',
#   'https://jamesclear.com/3-2-1/september-9-2021'],
#  ['August 22 2019',
#   ' On increasing intelligence, networking, and shooting for the top',
#   "Here's a simple question with potentially wide-reaching implications:",
#   'https://jamesclear.com/3-2-1/august-22-2019'],
#  ['August 29 2019',
#   ' On feeling misunderstood, thinking clearly, and making the most of your one life',
#   "Here's a question for you to ponder this week…",
#   'https://jamesclear.com/3-2-1/august-29-2019'],
#  ['August 20 2020',
#   ' On taking action, writing well, and motivating others',
#   'What is your personal compounding advantage in your career?',
#   'https://jamesclear.com/3-2-1/august-20-2020'],
#  ['September 16 2021',
#   ' The measure of success, courage, and knowing what you want',
#   'Was this a productive week? What can you do today to guarantee the answer is yes?',
#   'https://jamesclear.com/3-2-1/september-16-2021'],
#  ['May 21 2020',
#   ' Opportunity cost, power of listening, and the stories we tell ourselves',
#   'Simple question to find work you love:',
#   'https://jamesclear.com/3-2-1/may-21-2020'],
#  ['December 16 2021',
#   ' The difference between good and great, how to love yourself, and how to get better at writing',
#   'What am I continuing to do out of habit, but is no longer serving me?',
#   'https://jamesclear.com/3-2-1/december-16-2021'],
#  ['October 1 2020',
#   ' On scaling down your habits, obstacles, and finding time to do what matters',
#   "This week, I'll steal a question from Richard Hamming's fabulous talk,\xa0You and Your Research.",
#   'https://jamesclear.com/3-2-1/october-1-2020'],
#  ['March 26 2020',
#   ' Anticipation vs. expectation, how to write an ad, and the definition of love',
#   'Who is your biggest fan? How can you thank them today?',
#   'https://jamesclear.com/3-2-1/march-26-2020'],
#  ['October 7 2021',
#   ' The antidote to a bad day, teaching, and the healing power of story',
#   'What if you stopped trying to think your way through it and started to act your way through it?',
#   'https://jamesclear.com/3-2-1/october-7-2021'],
#  ['January 21 2021',
#   ' On fulfilling your potential, self-esteem, and the power of books',
#   'Has the most important thing changed? Am I chasing an outdated target?',
#   'https://jamesclear.com/3-2-1/january-21-2021'],
#  ['May 14 2020',
#   ' Entrepreneurship, habits, and the joy of climbing',
#   'Am I doing this for Present Me or Future Me?',
#   'https://jamesclear.com/3-2-1/may-14-2020'],
#  ['February 20 2020',
#   ' On failure, the importance of teaching, and handling the expectations of others',
#   'Whose expectations am I trying to fulfill? My own or those of someone else?',
#   'https://jamesclear.com/3-2-1/february-20-2020'],
#  ['August 12 2021',
#   ' Working harder vs. smarter, and focusing on what matters',
#   'What do I have planned for today that energizes me?',
#   'https://jamesclear.com/3-2-1/august-12-2021'],
#  ['September 24 2020',
#   ' On compliments, inversion, and the importance of high standards',
#   'Who brings out your best qualities? Can you take five minutes right now to schedule time with them?',
#   'https://jamesclear.com/3-2-1/september-24-2020'],
#  ['November 5 2020',
#   ' On asking permission, the trick to writing well, and the magic of reading',
#   'What part of this situation is under my control?',
#   'https://jamesclear.com/3-2-1/november-5-2020'],
#  ['September 12 2019',
#   ' On mistakes of ambition vs. sloth, innovation, and being reliable',
#   'Do you really need to think more, or is it simply a matter of doing the work?',
#   'https://jamesclear.com/3-2-1/september-12-2019'],
#  ['February 6 2020',
#   ' On success and failure, kindness and mortality, and taking action',
#   'What are the minority of my actions that drive the majority of my results?',
#   'https://jamesclear.com/3-2-1/february-6-2020'],
#  ['June 18 2020',
#   ' On the cycle of improvement, self-doubt, and building a spirit',
#   'What are you preventing yourself from feeling?',
#   'https://jamesclear.com/3-2-1/june-18-2020'],
#  ['December 3 2020',
#   ' On the best exercise, the secret to winning, and dealing with disappointment',
#   "Here's a question that a reader shared with me:",
#   'https://jamesclear.com/3-2-1/december-3-2020'],
#  ['February 3 2022',
#   ' How to be alone, taking action, and choosing your heroes',
#   'A question from Barrett Brooks on choosing your heroes:',
#   'https://jamesclear.com/3-2-1/february-3-2022'],
#  ['April 30 2020',
#   ' The 80/20 Principle, mastery, and the importance of asking questions',
#   'A simple question that may help reveal the positive side of the current moment:',
#   'https://jamesclear.com/3-2-1/april-30-2020'],
#  ['October 22 2020',
#   ' On simplifying, a 5-step process for nearly anything, and collaboration',
#   'What is the little bit of extra work that has huge upside?',
#   'https://jamesclear.com/3-2-1/october-22-2020'],
#  ['July 22 2021',
#   ' How to find opportunities, finishing what you start, and what it takes to improve',
#   'Do I actually need more information or do I simply need to act on the information I already have?',
#   'https://jamesclear.com/3-2-1/july-22-2021'],
#  ['December 19 2019',
#   ' On hard work and strategy, and changes sneaking up on you',
#   'What do you really wish you had the courage to do?',
#   'https://jamesclear.com/3-2-1/december-19-2019'],
#  ['October 10 2019',
#   ' On gut reactions, negotiation tips, perseverance, and making better decisions',
#   'What can you remove from your life that would improve it?',
#   'https://jamesclear.com/3-2-1/october-10-2019'],
#  ['October 24 2019',
#   ' On saying no, the importance of focus, and reading books',
#   'How can I prepare carefully, but execute quickly?',
#   'https://jamesclear.com/3-2-1/october-24-2019'],
#  ['September 23 2021',
#   ' Leave room for the unexpected',
#   'To prioritize the day, think about the decade:',
#   'https://jamesclear.com/3-2-1/september-23-2021'],
#  ['February 25 2021',
#   ' On eliminating clutter, reinventing yourself, and unity',
#   'A question from venture capitalist and executive coach, Jerry Colonna:',
#   'https://jamesclear.com/3-2-1/february-25-2021'],
#  ['December 30 2021',
#   ' Slowing down, letting go, and lessons from the year',
#   'What is one lesson you learned (or relearned) this year?',
#   'https://jamesclear.com/3-2-1/december-30-2021'],
#  ['May 27 2021',
#   ' On dealing with conflict, writing books, and working on the right level',
#   'Am I working at the right level? Do I need to zoom in or zoom out?',
#   'https://jamesclear.com/3-2-1/may-27-2021'],
#  ['March 10 2022',
#   ' Life’s seasons, the importance of rest, and the secret to feeling great about yourself',
#   'Write down all the projects you are working on right now. What is the one thing that, if you had the courage to eliminate it entirely, would make all the others easier?',
#   'https://jamesclear.com/3-2-1/march-10-2022'],
#  ['July 16 2020',
#   ' On learning from mistakes, complaining, and getting better at sales',
#   'Assume that more than one path exists to achieve your ideal life.',
#   'https://jamesclear.com/3-2-1/july-16-2020'],
#  ['March 18 2021',
#   ' On mediocrity vs. genius, taking risks, and when to ignore a problem',
#   'What could be improved? What could be removed?',
#   'https://jamesclear.com/3-2-1/march-18-2021'],
#  ['February 11 2021',
#   ' On copying best practices, being underestimated, and the difficulty of change',
#   'Does this activity fill me with energy or drain me of energy?',
#   'https://jamesclear.com/3-2-1/february-11-2021'],
#  ['December 23 2021',
#   ' Ending the year on a high note, maximizing your strength, and taking responsibility',
#   'What is something meaningful you can accomplish in the final week of the year?',
#   'https://jamesclear.com/3-2-1/december-23-2021'],
#  ['June 24 2021',
#   ' Starting from zero, and how to choose what to work on',
#   'People will tell stories about you at your funeral. What chapter are you writing today?',
#   'https://jamesclear.com/3-2-1/june-24-2021'],
#  ['February 18 2021',
#   ' On attracting luck, taking risks, and the ineffectiveness of anger',
#   'What do I actually want?',
#   'https://jamesclear.com/3-2-1/february-18-2021'],
#  ['September 26 2019',
#   ' On editing your own work, being original, and failure',
#   "This week's question builds on the quote from John Gardner above.",
#   'https://jamesclear.com/3-2-1/september-26-2019'],
#  ['November 4 2021',
#   ' The value of nature, controlling your attention, and designing your environment',
#   'Look around the rooms where you spend the most time.',
#   'https://jamesclear.com/3-2-1/november-4-2021'],
#  ['March 19 2020',
#   ' On focus, persistence, and misfortune',
#   'How can I make the most of this?',
#   'https://jamesclear.com/3-2-1/march-19-2020'],
#  ['March 11 2021',
#   ' On allowing yourself to be happy and full, and how small errors compound',
#   'What 6-month period of your life was the most energizing and fun?',
#   'https://jamesclear.com/3-2-1/march-11-2021'],
#  ['September 5 2019',
#   ' On problem solving, tough-minded optimism, and courage',
#   'Look at each item on your to-do list and ask, “Is this truly necessary?”',
#   'https://jamesclear.com/3-2-1/september-5-2019'],
#  ['February 4 2021',
#   ' On teaching, mastery, and working on important problems',
#   "Today's question comes from the engineer, Richard Hamming:",
#   'https://jamesclear.com/3-2-1/february-4-2021'],
#  ['March 17 2022',
#   ' Charity, the true mark of a pro, and how to choose what to read',
#   'Nearly everything in life has a useful zone, a desired dose. Ten minutes in the sun can energize you. Ten hours in the sun can burn you. This concept applies to many things: work, relationships, hobbies, exercise, food.',
#   'https://jamesclear.com/3-2-1/march-17-2022'],
#  ['July 23 2020',
#   ' On decision making, the value of friends, and self-improvement',
#   'Imagine each day is only 12 hours long. What would you cut out?',
#   'https://jamesclear.com/3-2-1/july-23-2020'],
#  ['October 17 2019',
#   ' On change, margin of safety, and handling criticism',
#   'Are things truly not going well … or do I just need some food, water, and a short break?\u200b',
#   'https://jamesclear.com/3-2-1/october-17-2019'],
#  ['March 4 2021',
#   ' On hate as a defense mechanism, reciprocity, and consistency',
#   'What are my actions moving me closer to?',
#   'https://jamesclear.com/3-2-1/march-4-2021'],
#  ['January 6 2022',
#   ' New perspectives, how to improve your thinking, and revising habits',
#   'Habits need to be revised from time to time.',
#   'https://jamesclear.com/3-2-1/january-6-2022'],
#  ['November 25 2021',
#   ' Gratitude, courage, and how to get more of what you want in life',
#   'At this time next year, what will you be thankful you spent time on during the next 12 months?',
#   'https://jamesclear.com/3-2-1/november-25-2021'],
#  ['June 25 2020',
#   ' On drivers of human behavior, reading, and focus',
#   'What can you work on today that will continue working for you years from now?',
#   'https://jamesclear.com/3-2-1/june-25-2020'],
#  ['February 24 2022',
#   ' Thinking clearly, being bold, and making each day a masterpiece',
#   "There is usually a block of time each day when you are at your best—\u200bpeak energy, peak enthusiasm. Let's say it's 2 hours per day. How do you spend those 2 hours? Who or what gets your best time?",
#   'https://jamesclear.com/3-2-1/february-24-2022'],
#  ['January 16 2020',
#   ' On getting started as a writer, the benefits of teaching, and growing old',
#   'In what ways are you a difficult person to work with?',
#   'https://jamesclear.com/3-2-1/january-16-2020'],
#  ['June 10 2021',
#   ' How to rebound from a mistake and think outside your constraints',
#   'What is one action that would make today a success?',
#   'https://jamesclear.com/3-2-1/june-10-2021'],
#  ['December 26 2019',
#   ' On kindness, real wealth, and earning love and respect',
#   'Over the last 10 years, what has become more important to you? What has become less important?',
#   'https://jamesclear.com/3-2-1/december-26-2019'],
#  ['July 1 2021',
#   ' Redefining hard work, taking action, and looking for happiness',
#   'What parts of my story no longer serve me? What stories am I attached to that I need to let go of?',
#   'https://jamesclear.com/3-2-1/july-1-2021'],
#  ['July 15 2021',
#   ' On unfinished projects, living a curious life, and the stories we tell ourselves',
#   'What happens if I slow down? What happens if I speed up?',
#   'https://jamesclear.com/3-2-1/july-15-2021'],
#  ['January 9 2020',
#   ' On your real priorities, living with purpose, and courage',
#   'What am I\xa0holding on to that I need to let go of this year?',
#   'https://jamesclear.com/3-2-1/january-9-2020'],
#  ['June 11 2020',
#   ' On the role of habits in times of uncertainty, hard work, and change',
#   'Which of my current habits serves me most? Which serves me least?',
#   'https://jamesclear.com/3-2-1/june-11-2020'],
#  ['December 5 2019',
#   ' On building better habits, focusing on the process, and optimism',
#   'What are you avoiding just because you know the answer is painful?',
#   'https://jamesclear.com/3-2-1/december-5-2019'],
#  ['September 2 2021',
#   ' Failure, mindset, and relationships',
#   "What's the cost of doing a poor job? What's the cost of doing a mediocre job? What's the cost of doing an exceptional job?",
#   'https://jamesclear.com/3-2-1/september-2-2021'],
#  ['January 20 2022',
#   ' Productivity, success, and 3 simple questions to improve your day',
#   'A question from writer and programmer\xa0Simon Sarris:',
#   'https://jamesclear.com/3-2-1/january-20-2022'],
#  ['July 2 2020',
#   ' On choosing the right goal, focus, and perseverance',
#   'Am I being good to myself?',
#   'https://jamesclear.com/3-2-1/july-2-2020'],
#  ['August 26 2021',
#   ' Being yourself, feeling unqualified, and win-win relationships',
#   'Am I being good to myself?',
#   'https://jamesclear.com/3-2-1/august-26-2021'],
#  ['October 28 2021',
#   ' Letting bad ideas die, the beauty of autumn, and the endless nature of craftsmanship',
#   'What is the biggest non-work related contribution you can make today?',
#   'https://jamesclear.com/3-2-1/october-28-2021'],
#  ['April 22 2021',
#   ' On the paradox of focus, criticism, and the value of reading',
#   'What is the biggest non-work related contribution you can make today?',
#   'https://jamesclear.com/3-2-1/april-22-2021'],
#  ['April 23 2020',
#   ' The paradox of risk, choosing the future, and treating the Earth well',
#   'Who do I know that can help me with this?',
#   'https://jamesclear.com/3-2-1/april-23-2020'],
#  ['January 7 2021',
#   ' On maturity, how to do exceptional work, and the connectedness of things',
#   'If you met someone exactly like yourself …',
#   'https://jamesclear.com/3-2-1/january-7-2021'],
#  ['October 31 2019',
#   ' On taking action, tips for writers, and good relationships',
#   'Am I happy with the tradeoffs I am making in my life right now?',
#   'https://jamesclear.com/3-2-1/october-31-2019'],
#  ['May 28 2020',
#   ' On seeing opportunities, originality, and the magic of books',
#   'If someone could only see my actions and not hear my words, what would they say are my priorities?',
#   'https://jamesclear.com/3-2-1/may-28-2020'],
#  ['October 21 2021',
#   ' Trying new ideas, preparation, and taking action',
#   'How much overlap is there between what you say is important to you and how you spent your attention over the last month?',
#   'https://jamesclear.com/3-2-1/october-21-2021'],
#  ['March 25 2021',
#   ' On obsessing over details, how to elicit feedback, and seeking what is significant',
#   'Does the amount of attention I’m giving this match its importance?',
#   'https://jamesclear.com/3-2-1/march-25-2021'],
#  ['April 2 2020',
#   ' Helping others, focus, and the difference between ambition and happiness',
#   'What is one thing I am looking forward to today?',
#   'https://jamesclear.com/3-2-1/april-2-2020'],
#  ['January 27 2022',
#   ' Assuming the best in others, savoring life, and a message of positivity',
#   'What is the most enjoyable five-minute stretch of your day? And how could you lengthen it to ten minutes?',
#   'https://jamesclear.com/3-2-1/january-27-2022'],
#  ['April 1 2021',
#   ' On mentors, margin of safety, and how to say no',
#   "How am I living with the results of other people's thinking?",
#   'https://jamesclear.com/3-2-1/april-1-2021'],
#  ['February 27 2020',
#   ' On creating meaning, the remarkable odds of your existence, and life instructions',
#   'What would 10-year-old me say? What would 80-year-old me say?',
#   'https://jamesclear.com/3-2-1/february-27-2020'],
#  ['October 29 2020',
#   ' On selective ignorance, courage, and living a life that burns bright',
#   'Who can I collaborate with to make this easier?',
#   'https://jamesclear.com/3-2-1/october-29-2020'],
#  ['November 21 2019',
#   ' On the highest level of mastery, being a positive force, and living a meaningful life',
#   'What is the most neglected important area in my life right now?',
#   'https://jamesclear.com/3-2-1/november-21-2019'],
#  ['February 17 2022',
#   ' New paths, the danger of complexity, and making fast decisions',
#   'What is something wonderful about your life that you rarely appreciate as much as you should?',
#   'https://jamesclear.com/3-2-1/february-17-2022'],
#  ['December 12 2019',
#   ' On your real priorities, living with purpose, and courage',
#   'Am I climbing the right mountain?',
#   'https://jamesclear.com/3-2-1/december-12-2019'],
#  ['June 17 2021',
#   ' How to get motivated and learn faster, and the power of attention',
#   'What is the limiting factor?',
#   'https://jamesclear.com/3-2-1/june-17-2021'],
#  ['December 31 2020',
#   ' On systems vs. goals, endings, and the importance of leverage',
#   'What is a mistake you seem to repeat each year? What can you do to prevent it this time?',
#   'https://jamesclear.com/3-2-1/december-31-2020'],
#  ['October 14 2021',
#   ' The secret to productivity and the power of collective hope',
#   'How can today feel like play?',
#   'https://jamesclear.com/3-2-1/october-14-2021'],
#  ['May 20 2021',
#   ' On excuses, a cure for sadness, and how beautiful people are made',
#   'A question from writer Elizabeth Gilbert:',
#   'https://jamesclear.com/3-2-1/may-20-2021'],
#  ['December 10 2020',
#   ' On choosing your pain, self-acceptance, and seizing opportunities',
#   'A question from writer Elizabeth Gilbert:',
#   'https://jamesclear.com/3-2-1/december-10-2020'],
#  ['September 10 2020',
#   ' On spending, compliments, and optimism',
#   'Is there a better way? Is there a kinder way?',
#   'https://jamesclear.com/3-2-1/september-10-2020'],
#  ['July 29 2021',
#   ' How to excel, the health benefits of friendship, and the importance of bad days',
#   'Faster. If I had to go from start to finish in half the time, what would I do?',
#   'https://jamesclear.com/3-2-1/july-29-2021'],
#  ['January 2 2020',
#   ' On systems vs. goals, identity-based habits, and the lessons of life',
#   'Think of the ultimate outcome you are hoping to achieve. Is there a path to accomplishing this where you would encounter less resistance?',
#   'https://jamesclear.com/3-2-1/january-2-2020'],
#  ['March 12 2020',
#   ' On media consumption, needless commitments, and persistence and luck',
#   'Which projects give me energy? Which projects takes it away?',
#   'https://jamesclear.com/3-2-1/march-12-2020'],
#  ['August 15 2019',
#   ' On mastery, learning to let go of trivial arguments, and bias',
#   "Here's a question for you to ponder this week…",
#   'https://jamesclear.com/3-2-1/august-15-2019'],
#  ['November 28 2019',
#   ' On freedom and responsibility, “bad” workouts, and obligations',
#   'Are your obligations real or imagined?',
#   'https://jamesclear.com/3-2-1/november-28-2019'],
#  ['November 12 2020',
#   ' On simplicity, having good ideas, and acting in the face of fear',
#   'What is one repeating problem you can automate or eliminate today?',
#   'https://jamesclear.com/3-2-1/november-12-2020'],
#  ['November 26 2020',
#   ' On social skills, gratitude, and making life count',
#   'Some questions to consider before you speak:',
#   'https://jamesclear.com/3-2-1/november-26-2020'],
#  ['August 5 2021',
#   ' A quick tip for building habits that last, and the connection between art and an open mind',
#   "Thanks to Bryan Harris for sharing this week's question with me:",
#   'https://jamesclear.com/3-2-1/august-5-2021'],
#  ['February 10 2022',
#   ' Success, getting started, and the unnoticed good in the world',
#   "Entrepreneur and investor Sam Altman says some of the best advice he ever received was, “If you can't figure out what kind of work you like, pay attention to what's easy to concentrate on and gives you energy vs. what makes you tune out and feel tired.”",
#   'https://jamesclear.com/3-2-1/february-10-2022'],
#  ['December 24 2020',
#   ' On the most important conversation, the value of time, and trusting your gut',
#   "Entrepreneur and investor Sam Altman says some of the best advice he ever received was, “If you can't figure out what kind of work you like, pay attention to what's easy to concentrate on and gives you energy vs. what makes you tune out and feel tired.”",
#   'https://jamesclear.com/3-2-1/december-24-2020'],
#  ['March 5 2020',
#   ' On taking risks, attracting good luck, and the benefits of rest',
#   'How would I know if my beliefs are wrong?',
#   'https://jamesclear.com/3-2-1/march-5-2020'],
#  ['September 17 2020',
#   ' On talent, qualities of a great career, and efficiency vs. effectiveness',
#   'If you keep living the way you are, what will your life look like in 20 years?',
#   'https://jamesclear.com/3-2-1/september-17-2020'],
#  ['April 15 2021',
#   ' On learning by doing, a rule to live by, and the seasons of life',
#   'How can I create an environment that will naturally bring about my desired change?',
#   'https://jamesclear.com/3-2-1/april-15-2021'],
#  ['August 13 2020',
#   ' On inspiration, how to lose, and building a successful business',
#   'What am I holding on to that I need to let go of?',
#   'https://jamesclear.com/3-2-1/august-13-2020'],
#  ['February 13 2020',
#   ' On wealth, learning, and love',
#   'A simple question to run your daily decisions through:',
#   'https://jamesclear.com/3-2-1/february-13-2020'],
#  ['October 15 2020',
#   ' On clear boundaries, handling criticism, and the importance of quality',
#   'Momentum is a double-edged sword. It can propel you to new heights or keep you locked into previous choices and old habits.',
#   'https://jamesclear.com/3-2-1/october-15-2020'],
#  ['July 8 2021',
#   ' How to give advice, and three steps to exceptional results',
#   'What is the most likely cause of failure?',
#   'https://jamesclear.com/3-2-1/july-8-2021'],
#  ['May 6 2021',
#   ' On judging your own work, and maintaining a mindset of flexibility',
#   'An insightful question from\xa0Steph Smith:',
#   'https://jamesclear.com/3-2-1/may-6-2021'],
#  ['November 14 2019',
#   ' On beginner’s mind, kindness, and time management',
#   'If you were forced to work for just one hour per day, what would you work on during that hour to be most effective?',
#   'https://jamesclear.com/3-2-1/november-14-2019'],
#  ['December 2 2021',
#   ' Resilience, growth, and a guiding question for new opportunities',
#   'A question from Paul Allen, the co-founder of Microsoft:',
#   'https://jamesclear.com/3-2-1/december-2-2021'],
#  ['October 8 2020',
#   ' On confidence, the power of going first, and being a generalist',
#   'A question from Paul Allen, the co-founder of Microsoft:',
#   'https://jamesclear.com/3-2-1/october-8-2020'],
#  ['July 9 2020',
#   ' On bottlenecks, losing track of time, and confident humility',
#   "What am I avoiding just because the desired outcome would take longer than I'd like?",
#   'https://jamesclear.com/3-2-1/july-9-2020'],
#  ['October 3 2019',
#   ' On the costs of habits, major life changes, and what money can’t buy',
#   "Here's a question for you to consider this week…",
#   'https://jamesclear.com/3-2-1/october-3-2019'],
#  ['August 6 2020',
#   ' On knowing what you want, feedback, and facing challenges',
#   'Am I being effective or just busy?',
#   'https://jamesclear.com/3-2-1/august-6-2020'],
#  ['April 29 2021',
#   ' On the bottleneck to achieving results, the discomfort of growth, and friendship',
#   'How have my bad habits become a crutch I lean on? What stories do I need to let go of so I can walk freely?',
#   'https://jamesclear.com/3-2-1/april-29-2021'],
#  ['April 16 2020',
#   ' On correcting mistakes, youth, and focus',
#   'Am I proud of what I am choosing to do?',
#   'https://jamesclear.com/3-2-1/april-16-2020'],
#  ['July 30 2020',
#   ' On the power of simple ideas, focus, and asking good questions',
#   'Which areas of my life are in maintenance mode? Which areas are in growth mode?',
#   'https://jamesclear.com/3-2-1/july-30-2020'],
#  ['August 8 2019',
#   ' On the lessons of history, imperfect starts, and critiquing your own work',
#   "Finally, here's a tough question to consider this week:",
#   'https://jamesclear.com/3-2-1/august-8-2019'],
#  ['November 18 2021',
#   ' On lucky events, saying thank you, and the value of ignoring some problems',
#   'What has been your favorite period of the last decade? How can you recreate some of that magic over the next year?',
#   'https://jamesclear.com/3-2-1/november-18-2021'],
#  ['April 8 2021',
#   ' Pushing yourself, listening, and a simple rule for life and work',
#   'What do I keep coming back to? What is that telling me?',
#   'https://jamesclear.com/3-2-1/april-8-2021'],
#  ['November 7 2019',
#   ' On social pressure, the power of choice, and the price of success',
#   'What is the biggest opportunity I could pursue in the next 5 minutes?',
#   'https://jamesclear.com/3-2-1/november-7-2019'],
#  ['January 28 2021',
#   ' On being in the right room, confidence, and taking action',
#   'What are you working on when time fades away?',
#   'https://jamesclear.com/3-2-1/january-28-2021'],
#  ['May 7 2020',
#   ' Creative ideas, wealth, and making life a celebration',
#   'What is something that feels productive to you in the moment, but usually ends up wasting time and energy?',
#   'https://jamesclear.com/3-2-1/may-7-2020'],
#  ['September 19 2019',
#   ' On comparison, consistency, and what’s not going to change',
#   'The people who have already walked through the fire can help you do the same. Who are you surrounding yourself with?\u200b',
#   'https://jamesclear.com/3-2-1/september-19-2019'],
#  ['November 11 2021',
#   ' How to approach life, and how to succeed as a writer',
#   "What is a small thing that bugs me, but I haven't taken the time to fix? Can I fix it today?",
#   'https://jamesclear.com/3-2-1/november-11-2021'],
#  ['January 13 2022',
#   ' Remaining a beginner, how geniuses work, and the next 60 seconds',
#   'How can I make the next 60 seconds as perfect and as present as possible?',
#   'https://jamesclear.com/3-2-1/january-13-2022'],
#  ['August 27 2020',
#   ' On building habits that last and the link between success and failure',
#   'What is one thing you can accomplish today that would make this day a success?',
#   'https://jamesclear.com/3-2-1/august-27-2020'],
#  ['September 30 2021',
#   ' How to build a career in 7 steps, paying attention to boredom, and setting boundaries',
#   'In what areas would you benefit from setting clearer boundaries?',
#   'https://jamesclear.com/3-2-1/september-30-2021'],
#  ['January 14 2021',
#   ' A brief guide to leadership, and when to value feedback',
#   'A simple question that can deliver powerful results if taken seriously:',
#   'https://jamesclear.com/3-2-1/january-14-2021']]

# %%
# so now we got all the newsletters and the questions 
len(all_newsletter_data)
# Out:
# 137

# %%
# now lets make a dataframe from all the data we collected:
df = pd.DataFrame(all_newsletter_data, columns= ["date", "title","1_question_for_you", "link"])
df.head(5)
# Out:
#                date                                              title  \
# 0       June 3 2021   On growth, all-or-nothing mindsets, and how g...
# 1   December 9 2021   Active patience, focusing on what you can con...
# 2       June 4 2020   On taking action, changing incentives, and be...
# 3      March 3 2022   Doubling your intelligence, zooming out, and ...
# 4  December 17 2020   On blame, the purpose of education, and compo...
#
#                                   1_question_for_you  \
# 0  Do the people around me act the way I wish to ...
# 1              Are you playing a game worth winning?
# 2  What is the biggest small thing I could do today?
# 3  Think of something you struggled with in the l...
# 4  What is one small thing I could do today that ...
#
#                                             link
# 0       https://jamesclear.com/3-2-1/june-3-2021
# 1   https://jamesclear.com/3-2-1/december-9-2021
# 2       https://jamesclear.com/3-2-1/june-4-2020
# 3      https://jamesclear.com/3-2-1/march-3-2022
# 4  https://jamesclear.com/3-2-1/december-17-2020

# %% [markdown]
# ### All in one

# %%
all_newsletter_data = []

def get_links():
    """Extract all the links to the newsletters"""
    r = session.get('https://jamesclear.com/3-2-1')
    nl_links= [link for link in r.html.absolute_links if "/3-2-1/" in link]
    return nl_links

def get_newsletter_questions():
    """Extract the date, title, question and link for all newsletter"""
    for nl in nl_links:
        ra = session.get(nl)
        title = ra.html.find("div.page__header>h1", first=True).text.replace("3-2-1:", "")
        url = ra.url
        date = url.rsplit("/")[4].replace('-',' ').capitalize()
        try:
            question = ra.html.find("h2#h-1-question-for-you~p", first=True).full_text.strip()
        except:
            pass
        all_newsletter_data.append([date, title, question, url ])
    df = pd.DataFrame(all_newsletter_data, columns= ["date", "title","1_question_for_you", "link"])
    return df

# %% [markdown]
# **Now we can call the functions to get the data:**

# %%
get_links(), get_newsletter_questions()
# Out:
# (['https://jamesclear.com/3-2-1/june-3-2021',
#   'https://jamesclear.com/3-2-1/december-9-2021',
#   'https://jamesclear.com/3-2-1/june-4-2020',
#   'https://jamesclear.com/3-2-1/march-3-2022',
#   'https://jamesclear.com/3-2-1/december-17-2020',
#   'https://jamesclear.com/3-2-1/january-23-2020',
#   'https://jamesclear.com/3-2-1/august-19-2021',
#   'https://jamesclear.com/3-2-1/january-30-2020',
#   'https://jamesclear.com/3-2-1/october-3-2019',
#   'https://jamesclear.com/3-2-1/august-6-2020',
#   'https://jamesclear.com/3-2-1/april-29-2021',
#   'https://jamesclear.com/3-2-1/april-16-2020',
#   'https://jamesclear.com/3-2-1/july-30-2020',
#   'https://jamesclear.com/3-2-1/august-8-2019',
#   'https://jamesclear.com/3-2-1/november-18-2021',
#   'https://jamesclear.com/3-2-1/april-8-2021',
#   'https://jamesclear.com/3-2-1/november-7-2019',
#   'https://jamesclear.com/3-2-1/january-28-2021',
#   'https://jamesclear.com/3-2-1/may-7-2020',
#   'https://jamesclear.com/3-2-1/september-19-2019',
#   'https://jamesclear.com/3-2-1/november-11-2021',
#   'https://jamesclear.com/3-2-1/january-13-2022',
#   'https://jamesclear.com/3-2-1/august-27-2020',
#   'https://jamesclear.com/3-2-1/september-30-2021',
#   'https://jamesclear.com/3-2-1/january-14-2021'],
#                    date                                              title  \
#  0          June 3 2021   On growth, all-or-nothing mindsets, and how g...
#  1      December 9 2021   Active patience, focusing on what you can con...
#  2          June 4 2020   On taking action, changing incentives, and be...
#  3         March 3 2022   Doubling your intelligence, zooming out, and ...
#  4     December 17 2020   On blame, the purpose of education, and compo...
#  ..                 ...                                                ...
#  132   November 11 2021   How to approach life, and how to succeed as a...
#  133    January 13 2022   Remaining a beginner, how geniuses work, and ...
#  134     August 27 2020   On building habits that last and the link bet...
#  135  September 30 2021   How to build a career in 7 steps, paying atte...
#  136    January 14 2021   A brief guide to leadership, and when to valu...
#
#                                      1_question_for_you  \
#  0    Do the people around me act the way I wish to ...
#  1                Are you playing a game worth winning?
#  2    What is the biggest small thing I could do today?
#  3    Think of something you struggled with in the l...
#  4    What is one small thing I could do today that ...
#  ..                                                 ...
#  132  What is a small thing that bugs me, but I have...
#  133  How can I make the next 60 seconds as perfect ...
#  134  What is one thing you can accomplish today tha...
#  135  In what areas would you benefit from setting c...
#  136  A simple question that can deliver powerful re...
#
#                                                 link
#  0          https://jamesclear.com/3-2-1/june-3-2021
#  1      https://jamesclear.com/3-2-1/december-9-2021
#  2          https://jamesclear.com/3-2-1/june-4-2020
#  3         https://jamesclear.com/3-2-1/march-3-2022
#  4     https://jamesclear.com/3-2-1/december-17-2020
#  ..                                              ...
#  132   https://jamesclear.com/3-2-1/november-11-2021
#  133    https://jamesclear.com/3-2-1/january-13-2022
#  134     https://jamesclear.com/3-2-1/august-27-2020
#  135  https://jamesclear.com/3-2-1/september-30-2021
#  136    https://jamesclear.com/3-2-1/january-14-2021
#
#  [137 rows x 4 columns])

# %% [markdown]
# **Now lets save the data to a `.csv` file**

# %%
df.to_csv('JC_questions.csv', index=False)

# %% [markdown]
# **But what if we would like to get all the text from one newsletter?**

# %%
# It's easy to get all the data from the newsletter, but it can be a lot of text and not so easy to read in the notebook. 
get_one_nl = session.get(nl_links[5])
h_post = get_one_nl.html.find('h2')
p_post = get_one_nl.html.find('div p')
all_h = ([h.text for h in h_post])
all_p = ([p.text for p in p_post])
all_h, all_p
# Out:
# (['3 IDEAS FROM ME', '2 QUOTES FROM OTHERS', '1 QUESTION FOR YOU', 'Join Me'],
#  ['I.',
#   '“Focus is the art of knowing what to ignore.”',
#   'II.',
#   '“On minimalism:',
#   'The goal is not to have the least amount of things, but the optimal amount of things.',
#   'Two important footnotes:',
#   '(1) The optimal amount depends on your goals.\n(2) The optimal amount is almost always less than you think.”',
#   'III.',
#   '“Reading is like a software update for your brain.',
#   "Whenever you learn a new concept or idea, the ‘software' improves. You download new features and fix old bugs.",
#   'In this way, reading a good book can give you a new way to view your life experiences. Your past is fixed, but your interpretation of it can change depending on the software you use to analyze it.”',
#   'I.',
#   'Jeffrey D. Sachs, an economist and author, on money, spending, and status:',
#   '“Living doesn’t cost much, but showing off does.”',
#   'Source: The Price of Civilization: Reawakening American Virtue and Prosperity',
#   'II.',
#   'Seneca, one of the great Roman Stoic philosophers,\xa0on friendship:',
#   '“…nothing delights the mind so much as fond and loyal friendship. What a blessing it is to have hearts that are ready and willing to receive all your secrets in safety, with whom you are less afraid to share knowledge of something than keep it to yourself, whose conversation soothes your distress, whose advice helps you make up your mind, whose cheerfulness dissolves your sorrow, whose very appearance cheers you up!”',
#   'Source:\xa0On the Shortness of Life by Seneca',
#   'Am I tolerating my flaws or improving them?',
#   'Until next week,',
#   'James Clear\nAuthor of the million-copy bestseller,\xa0Atomic Habits\nCreator of The Habits Academy and the\xa0Habit Journal',
#   'P.S.\xa0Hello, this is the IRS.',
#   'Thanks for reading. You can get more actionable ideas in my popular email newsletter. Each week, I share 3 short ideas from me, 2 quotes from others, and 1 question to think about. Over 1,000,000 people subscribe. Enter your email now and join us.',
#   'The 3-2-1 Newsletter is one of the most popular newsletters in the world. Over 1,000,000 people subscribe. Each issue contains 3 short ideas from James Clear, 2 quotes from other people, and 1 question for you.',
#   'Learn more and sign up →'])

# %% [markdown]
# ### Summery

# %% [markdown]
# In summery we learned to get data from one of the most popular newsletters online, by the author and blogger James Clear. We explored how to get the data with the libraries `requests` and `beatiful soup` and the more integrated library `requests-html`. The `requests-html` we could get the job done with less then 20 of code.
#
# The result is a list of 137 interesting question to ponder and to make you think, with date, newsletter title, question and link to the full newsletter.
#
# For further work it would be interesting to explore getting data via an API, both an official one and via a `.json` call. Furthermore it would be great to get all the data and explore more ways to work with text in python and pandas.
#
# **A reminder, this is only serving as a learning notebook. Please check site/robots.txt before you start webscraping to make sure what is allowed to scrape, if anything, on the site you are interested in. Webscraping lots of data may get you baned as this may increase the site bandwith required and be associated with incressed hosting costs, so please be mindful and don't abuse this tool.**
#
# /AG

# %% [markdown]
# ### Further reading / Resources:
# - [Requests-HTML: The modern way of web scraping](https://medium.com/analytics-vidhya/the-modern-way-of-web-scraping-requests-html-2567ba2554f4)
# - [Web Scraping with Python Guide](https://youtu.be/J91bHusPatc) video
# - [Slow Web Scraper? Try this with ASYNC and Requests-html](https://youtu.be/8drEB06QjLs) video
# - [Python Tutorial: Web Scraping with Requests-HTML](https://youtu.be/a6fIbtFB46g) video
