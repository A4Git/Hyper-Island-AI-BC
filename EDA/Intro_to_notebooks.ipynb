# %% [markdown]
# <a href="https://colab.research.google.com/github/A4Git/Hyper-Island-AI-BC/blob/main/Intro_to_notebooks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hyper Island AIBC '23
# ## Intro to Data analysis and Pandas using Notebook

# %% [markdown]
# <a href="https://ibb.co/cTc2kWQ"><img src="https://i.ibb.co/JkRrmYH/carlos-muza-hpj-Sk-U2-UYSU-unsplash.jpg" alt="carlos-muza-hpj-Sk-U2-UYSU-unsplash" border="0"></a>
#
# This notebooks covers the following topics:
# ### Outline:
#
# 1. Coding in python, IDE's and Code editors
# 2. What are Jupyter Notebooks?
#     - How and where to run them?
# 3. The pros and cons of notebooks
# 4. What is Data analysis?
# 5. Further Reading and Resources
# 6. Explore a dataset with Pandas

# %% [markdown]
# ---

# %% [markdown]
# # 1. Coding in python, IDE's vs Code editors

# %% [markdown]
# ## Writing python code
# - Code Editors like [VIM](https://www.vim.org/), [Nano](https://www.nano-editor.org/), notepad.
#
# - IDE's (Integrated development environment) [VS Code](https://code.visualstudio.com/), [Atom](https://atom.io/), [Sublime text](https://www.sublimetext.com/)
# - CLI - Command line interface
# - Notebooks?

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# ---

# %% [markdown]
# # 2. What are Jupyter Notebooks?
#
# > The Jupyter Notebook is an open-source web application that **allows you to create and share documents that contain live code, equations, visualizations and narrative text**. Uses include: data cleaning and transformation, numerical simulation, statistical modeling, data visualization, machine learning, and much more.
#
#
# This tutorial is a [Jupyter notebook](https://jupyter.org) - a document made of _cells_. Each cell can contain code written in Python or explanations in plain English. You can execute code cells and view the results, e.g., numbers, messages, graphs, tables, files, etc., instantly within the notebook. Jupyter is a powerful platform for experimentation and analysis. Don't be afraid to mess around with the code & break things - you'll learn a lot by encountering and fixing errors. You can use the "Kernel > Restart & Clear Output" menu option to clear all outputs and start again from the top.

# %% [markdown]
# ### 2.1 Diffrent ways to ways to work with notebooks:
#
# - On your own computer, with [Anaconda](https://www.anaconda.com/products/individual)
# - Cloud solutions, for example:
#   - [Deepnote.com](https://deepnote.com/referral?token=49088dc9) - Get 20 free Pro hours by using this link.
#   - [Binder](https://mybinder.org/)
#   - [Kaggle](https://www.kaggle.com/code)
#   - [Google COLAB](https://colab.research.google.com/)
#     - [Short intro here](https://colab.research.google.com/notebooks/intro.ipynb)
#     - [Overview of basic features](https://colab.research.google.com/notebooks/basic_features_overview.ipynb)
#
#
# * The alternatives for working with data
#     - Excel
#     - [Tableau](https://www.tableau.com/) / [Power BI](https://powerbi.microsoft.com/en-us/)
#     - KNIME
#     - QlikView
#     - Apache Spark

# %% [markdown]
# ### 2.2 Why use notebooks?
# | The Pros:  | The Cons: |
# |:---|:---|
# |- Live enviorment | - Non liniar workflow  |
# |- Increased readability| - Harder to integrate in "production"  |
# |- Easy tool for colaboration with non technical people |  - Easy to mess it up|
# |- The code, the output and the docs in one place|   |

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## 3. What is Data analysis?
# > A process of **inspecting, cleansing, transforming** and **modeling data** with the goal of **discovering useful information, informing conclusion and supporting decision-making**. *Definition by [Wikipedia](https://en.wikipedia.org/wiki/Data_analysis)*

# %% [markdown]
# ![DA_Flow.png](data:image/png;base64,...)

# %% [markdown]
# ### **The goal**  ➡ Making sense of information to create value for different use cases
# ### **The scope** ➡ doing the right analysis:
#
# 1. Descriptive Analysis Goal ➡ Describe or Summarize a set of Data answering What happened?
#
# 2. Exploratory Analysis. ➡ Explores data to find relationships between measures that tells us they exist, without the cause. They can be u:sed to formulate hypotheses.
#
# 3. Inferential Analysis.➡ Extrapolates and generalizes the information of the larger group with a smaller sample to generate analysis and predictions.
#
# 4. Predictive Analysis.➡ Takes the data from the past and present to make predictions about the future.
#
# 5. Causal Analysis. ➡ Looks at the cause and effect of relationships between variables, focused on finding the cause of a correlation.
#
# 6. Mechanistic Analysis.➡ Understand exact changes in variables that lead to other changes in other variables
#
#
#
# [source](https://bit.ly/3kUM6Qc)

# %% [markdown]
# > Framing the problem and the scope of the analysis is very important for the end result of the analysis.

# %% [markdown]
# ## 4. What is pandas?
#
# <a href="https://ibb.co/QbGRmVK"><img src="https://i.ibb.co/JBP4kTs/Pandas.jpg" alt="Pandas" border="0"></a>
#
# pandas is a software library written for the Python programming language for data manipulation and analysis. In particular, it offers data structures and operations for manipulating numerical tables and time series.

# %% [markdown]
# # 5. Further Reading and Resources
#
# **Pandas Docs:**
# * [Pandas 10 min guide](https://pandas.pydata.org/docs/user_guide/10min.html) and the [User guide](https://pandas.pydata.org/docs/user_guide/index.html#user-guide)
#
# **Courses:**
# * [Data Analysis with Python: Zero to Pandas](https://jovian.ai/learn/data-analysis-with-python-zero-to-pandas) by Jovian
# * Datacamp [Data Manipulation with pandas](https://app.datacamp.com/learn/courses/data-manipulation-with-pandas)
#
#
# **Books:**
#
#   - [**Python for Data Analysis, 2nd Edition, by Wes McKinney (the creator of Pandas).**](https://www.oreilly.com/library/view/python-for-data/9781491957653/)  -  [The Github notebooks from the book](https://github.com/wesm/pydata-book)
#
# **Tutorials:**
# * Python Tutorial at W3Schools: https://www.w3schools.com/python/
# * Practical Python Programming: https://dabeaz-course.github.io/practical-python/Notes/Contents.html
# * Python official documentation: https://docs.python.org/3/tutorial/index.html
# * [Sentdex - Data Analysis and Data Science with Python and Pandas](https://youtu.be/nLw1RNvfElg)

# %% [markdown]
# ---

# %% [markdown]
# # 6. Explore a dataset with Pandas
#
# Now let's explore a dataset with the Pandas library in this **[notebook](https://github.com/A4Git/Hyper-Island-AI-BC/blob/main/HyperIsland_python_pandas_data_analysis.ipynb)** that is a modified version of the lecture 4 from the [Data Analysis with Python: Zero to Pandas ](https://jovian.ai/learn/data-analysis-with-python-zero-to-pandas)course by Jovian.ai.
